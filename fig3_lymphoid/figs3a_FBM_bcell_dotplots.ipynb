# %% [markdown]
# # Import packages and data

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import seaborn as sns
import scipy.stats
import anndata
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.axes._axes import _log as matplotlib_axes_logger
from scipy import sparse
matplotlib_axes_logger.setLevel('ERROR')
# Out:
# /Users/b8058304/.pyenv/versions/3.6.4/envs/py36/lib/python3.6/site-packages/anndata/_core/anndata.py:21: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import RangeIndex

# %%
sc.settings.verbosity = 1  # verbosity: errors (0), warnings (1), info (2), hints (3)
# Set up the plot config for viewing the annotation clearly.
sc.settings.set_figure_params(dpi=120, dpi_save=1000)
sc.logging.print_versions()
# Out:
# scanpy==1.4.4 anndata==0.7.1 umap==0.3.10 numpy==1.17.1 scipy==1.4.1 pandas==1.0.5 scikit-learn==0.22.2.post1 statsmodels==0.11.1 python-igraph==0.8.0 louvain==0.6.1

# %% [markdown]
# # Load FBM B lineage

# %%
adata = sc.read('/Users/b8058304/Documents/PhD_work/Coding/bm_plus_19pcw/data/bm_plus_19pcw_raw_dr_20200713.h5ad')

# %%
adata.raw = adata

# %%
cell_numbers = adata.obs.groupby(["cell.labels"]).apply(len)
cell_numbers
# Out:
# cell.labels
# CD4 T cell             327
# CD8 T cell             171
# CD14 monocyte         8787
# CD56 bright NK         540
# CMP                    425
#                       ...
# schwann cells            9
# sinusoidal EC          550
# stromal macrophage    1493
# tDC                    193
# tip EC                 363
# Length: 64, dtype: int64

# %%
lymphoid_celltypes = ['pre pro B progenitor', 'pro B progenitor', 'pre B progenitor', 'immature B cell', 
                     'naive B cell']

# %%
adata = adata[adata.obs['cell.labels'].isin(lymphoid_celltypes)].copy()

# %%
cell_numbers = adata.obs.groupby(["cell.labels"]).apply(len)
cell_numbers
# Out:
# cell.labels
# immature B cell          1998
# naive B cell             1423
# pre B progenitor        14234
# pre pro B progenitor     5428
# pro B progenitor         5530
# dtype: int64

# %%
adata.shape
# Out:
# (28613, 33712)

# %% [markdown]
# # Pre-process the dataset

# %%
# normalise count data 
sc.pp.normalize_total(adata)

# %%
# log the count data 
sc.pp.log1p(adata)

# %%
# find variable genes
sc.pp.highly_variable_genes(adata, min_mean=0.0125, max_mean=3, min_disp=0.5)

# %%
# scale the data 
sc.pp.scale(adata, max_value=10)

# %%
# scale the negative values in adata.X (which have been normalised, logged and scaled) to zero 
adata.X = np.where(adata.X < 0, 0, adata.X)

# %% [markdown]
# # Run dotplot

# %%
genes = ['SPINK2',
'CD34',
'FLT3',
'IL7R',
'CDC45',
'DHFR',
'UHRF1',
'DNTT',
'VPREB1',
'RAG1',
'MME',
'IDH2',
'CD19', #-- this is a switch from PCNA
'SPIB',
'IGHM',
'IGHD',
'MS4A1',
'CD40',
'FCER2']

# %%
adata.obs["cell.labels"] = adata.obs["cell.labels"].cat.reorder_categories(['pre pro B progenitor', 
                     'pro B progenitor', 'pre B progenitor', 'immature B cell', 
                     'naive B cell'])

# %%
sc.settings.set_figure_params(dpi=120, dpi_save=1000)
sc.pl.dotplot(adata, var_names=genes, groupby="cell.labels", use_raw=False, save="figs3a_bcell_dotplot_20200717.pdf")
# Out:
# WARNING: saving figure to file figures/dotplotfigs3a_bcell_dotplot_20200717.pdf
# GridSpec(2, 5, height_ratios=[0, 10.5], width_ratios=[6.6499999999999995, 0, 0.2, 0.5, 0.25])

# %% [markdown]
# # Save the data

# %%
from scipy.sparse import csr_matrix
adata.X = sparse.csr_matrix(adata.X)

# %%
adata.X
# Out:
# <28613x33712 sparse matrix of type '<class 'numpy.float32'>'
# 	with 59828587 stored elements in Compressed Sparse Row format>

# %%
adata.raw.X
# Out:
# <28613x33712 sparse matrix of type '<class 'numpy.float32'>'
# 	with 66928538 stored elements in Compressed Sparse Row format>

# %%
adata.write("/Users/b8058304/Documents/PhD_work/Coding/manuscript_figs/data/figs3a_bcell_dotplot_20200717.h5ad")
