# %% [markdown]
# # Import packages and data

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import seaborn as sns
import scipy.stats
import anndata
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.axes._axes import _log as matplotlib_axes_logger
from scipy import sparse
matplotlib_axes_logger.setLevel('ERROR')
import warnings
warnings.filterwarnings('ignore')
# Out:
# /Users/b8058304/.pyenv/versions/3.6.4/envs/py36/lib/python3.6/site-packages/anndata/_core/anndata.py:21: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import RangeIndex

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
sc.settings.verbosity = 1  # verbosity: errors (0), warnings (1), info (2), hints (3)
# Set up the plot config for viewing the annotation clearly.
sc.settings.set_figure_params(dpi=120, dpi_save=1000)
sc.logging.print_versions()
# Out:
# scanpy==1.4.4 anndata==0.7.1 umap==0.3.10 numpy==1.17.1 scipy==1.4.1 pandas==1.0.5 scikit-learn==0.22.2.post1 statsmodels==0.11.1 python-igraph==0.8.0 louvain==0.6.1

# %% [markdown]
# # Load FBM B lineage

# %%
adata = sc.read("/Users/b8058304/Documents/PhD_work/Coding/manuscript_figs_mk2/data/fig3a_bcell_dr_20210115.h5ad")

# %% [markdown]
# # Plot FDG by apoptotic enrichment

# %%
sc.pl.draw_graph(adata, color=['cell.labels'], layout='fa')

# %%
# https://www.gsea-msigdb.org/gsea/msigdb/cards/KEGG_APOPTOSIS as of 25/06/2020

apoptotic_KEGG_genes = ['AC093012.1',
'AIFM1',
'AKT1',
'AKT2',
'AKT3',
'APAF1',
'ATM',
'BAD',
'BAX',
'BCL2',
'BCL2L1',
'BID',
'BIRC2',
'BIRC3',
'CAPN1',
'CAPN2',
'CASP10',
'CASP3',
'CASP6',
'CASP7',
'CASP8',
'CASP9',
'CFLAR',
'CHP1',
'CHP2',
'CHUK',
'CSF2RB',
'CYCS',
'DFFA',
'DFFB',
'ENDOD1',
'ENDOG',
'EXOG',
'FADD',
'FAS',
'FASLG',
'IKBKB',
'IKBKG',
'IL1A',
'IL1B',
'IL1R1',
'IL1RAP',
'IL3',
'IL3RA',
'IRAK1',
'IRAK2',
'IRAK3',
'MAP3K14',
'MYD88',
'NFKB1',
'NFKBIA',
'NGF',
'NTRK1',
'PIK3CA',
'PIK3CB',
'PIK3CD',
'PIK3CG',
'PIK3R1',
'PIK3R2',
'PIK3R3',
'PIK3R5',
'PPP3CA',
'PPP3CB',
'PPP3CC',
'PPP3R1',
'PPP3R2',
'PRKACA',
'PRKACB',
'PRKACG',
'PRKAR1A',
'PRKAR1B',
'PRKAR2A',
'PRKAR2B',
'PRKX',
'RELA',
'RIPK1',
'TNF',
'TNFRSF10A',
'TNFRSF10B',
'TNFRSF10C',
'TNFRSF10D',
'TNFRSF1A',
'TNFSF10',
'TP53',
'TRADD',
'TRAF2',
'XIAP']

sc.tl.score_genes(adata, gene_list=apoptotic_KEGG_genes, score_name="apoptotic_enrichment")
# Out:
# WARNING: gene: AC093012.1 is not in adata.var_names and will be ignored

# %%
sc.pl.draw_graph(adata, color=['apoptotic_enrichment'], layout='fa', size=20,  
                 show=True, save='_fig3a_apoptotic_enrichment_cell_labels_legoff_20210115.pdf') #, vmin=-1, vmax=3)
# Out:
# WARNING: saving figure to file figures/draw_graph_fa_fig3a_apoptotic_enrichment_cell_labels_legoff_20210115.pdf
