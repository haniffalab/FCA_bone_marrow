# %% [markdown]
# # Import packages and data

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import seaborn as sns
import scipy.stats
import anndata
import matplotlib.pyplot as plt
import matplotlib as mpl
import rpy2

# %%
sc.settings.verbosity = 1  # verbosity: errors (0), warnings (1), info (2), hints (3)
# Set up the plot config for viewing the annotation clearly.
sc.settings.set_figure_params(dpi=120, dpi_save=1000)
sc.logging.print_versions()
# Out:
# scanpy==1.4.4 anndata==0.7.1 umap==0.3.10 numpy==1.17.1 scipy==1.4.1 pandas==0.23.0 scikit-learn==0.22.2.post1 statsmodels==0.11.1 python-igraph==0.8.0 louvain==0.6.1

# %% [markdown]
# # Load the resident and progenitor subsets

# %%
adata = sc.read('/Users/b8058304/Documents/PhD_work/Coding/bm_plus_19pcw/data/bm_plus_19pcw_raw_dr_20201007.h5ad')

# %%
adata.raw = adata

# %%
cell_numbers = adata.obs.groupby(["cell.labels"]).apply(len)
cell_numbers
# Out:
# cell.labels
# CD4 T cell                   327
# CD8 T cell                   171
# CD14 monocyte               8763
# CD56 bright NK               449
# CMP                          425
# DC1                           50
# DC2                          598
# DC3                          705
# DC precursor                 201
# ELP                         1357
# GMP                         1281
# HSC                           92
# ILC precursor                 67
# LMPP                          34
# MEMP                          16
# MEP                          269
# MK                          1000
# MOP                         3838
# MPP myeloid                   92
# NK T cell                    111
# NK progenitor                 26
# Treg                          62
# adipo-CAR                    353
# arteriolar fibroblast         83
# basophil                     139
# chondrocyte                   80
# early MK                    1624
# early erythroid             7474
# ...

# %%
celltypes = ['sinusoidal EC', 'proliferating EC', 'tip EC', 'arteriolar fibroblast',
            'adipo-CAR', 'endosteal fibroblast', 'osteochondral precursor', 'osteoblast precursor', 
            'early osteoblast', 'stromal macrophage', 'myofibroblast', 'HSC']

# %%
adata = adata[adata.obs['cell.labels'].isin(celltypes)].copy()

# %%
cell_numbers = adata.obs.groupby(["cell.labels"]).apply(len)
cell_numbers
# Out:
# cell.labels
# HSC                          92
# adipo-CAR                   353
# arteriolar fibroblast        83
# early osteoblast            280
# endosteal fibroblast         54
# myofibroblast                78
# osteoblast precursor        456
# osteochondral precursor     191
# proliferating EC             26
# sinusoidal EC               550
# stromal macrophage         1464
# tip EC                      362
# dtype: int64

# %%
adata.shape
# Out:
# (3989, 33712)

# %% [markdown]
# # Pre-process the dataset

# %%
# normalise count data 
sc.pp.normalize_total(adata)

# %%
# log the count data 
sc.pp.log1p(adata)

# %%
# find variable genes
sc.pp.highly_variable_genes(adata, min_mean=0.0125, max_mean=3, min_disp=0.5)

# %%
# scale the data 
sc.pp.scale(adata, max_value=10)

# %%
# scale the negative values in adata.X (which have been normalised, logged and scaled) to zero 
adata.X = np.where(adata.X < 0, 0, adata.X)

# %% [markdown]
# # Run dotplots for HSC signalling to stroma

# %%
HSC_genes = ['TNFRSF10C',
'ESAM',
'CD44',
'NOTCH1',
'NOTCH2',
'NOTCH1',
'NOTCH2',
'NRP2',
'FGFR1',
'CD74',
'SELL',
'PLAUR',
'PLAUR',
'KIT',
'CD46',
'NOTCH1',
'LAMP1',
'HLA-C',
'HLA-DRB1',
'NOTCH1',
'NRP2',
'NRP2',
'HLA-DPA1',
'HLA-DPA1',
'PLXNC1',
'FGFR1',
'FGFR1',
'FGFR1',
'ICAM4',
'ICAM3',
'JAM3',
'LAIR1',
'SPN',
'ICAM3',
'HLA-DPB1',
'TNFRSF1B',
'TNFRSF1A',
'PGRMC2',
'NPR3',
'MERTK',
'FLT3']
             
stromal_genes = ['TNFSF10',
'ESAM',
'SELE',
'JAG2',
'JAG2',
'DLL4',
'DLL4',
'SEMA3F',
'FGF7',
'APP',
'CD34',
'ITGA4',
'ITGB1',
'KITLG',
'JAG1',
'JAG1',
'FAM3C',
'FAM3C',
'OGN',
'NOV',
'VEGFA',
'PGF',
'GAL',
'TNFSF9',
'SEMA7A',
'FGFR2',
'NCAM1',
'NCAM1',
'ITGAL',
'ITGB2',
'ITGAM',
'LILRB4',
'SIGLEC1',
'CD209',
'TNFSF13B',
'GRN',
'GRN',
'CCL4L2',
'NPPC',
'GAS6',
'FLT3LG']

# %%
sc.settings.set_figure_params(dpi=120, dpi_save=1000)

subset = adata[adata.obs['cell.labels'].isin(['HSC'])].copy()

sc.pl.dotplot(subset, var_names=HSC_genes, groupby="cell.labels", use_raw=False, 
              save="figs11b_hsc_dotplot_20210430.pdf", vmax=2) #dot_max=0.2,
# Out:
# WARNING: saving figure to file figures/dotplotfigs11b_hsc_dotplot_20210430.pdf
# GridSpec(2, 5, height_ratios=[0, 10.5], width_ratios=[14.35, 0, 0.2, 0.5, 0.25])

# %%
sc.settings.set_figure_params(dpi=120, dpi_save=1000)

subset = adata[adata.obs['cell.labels'].isin(['sinusoidal EC', 'proliferating EC', 
            'tip EC', 'arteriolar fibroblast', 'adipo-CAR', 'endosteal fibroblast', 'osteochondral precursor', 
            'osteoblast precursor', 'early osteoblast', 'stromal macrophage', 'myofibroblast'])].copy()

subset.obs["cell.labels"] = subset.obs["cell.labels"].cat.reorder_categories(['sinusoidal EC', 'proliferating EC', 
            'tip EC', 'arteriolar fibroblast', 'adipo-CAR', 'endosteal fibroblast', 'osteochondral precursor', 
            'osteoblast precursor', 'early osteoblast', 'stromal macrophage', 'myofibroblast'])

sc.pl.dotplot(subset, var_names=stromal_genes, groupby="cell.labels", use_raw=False, 
              save="figs11b_stroma_dotplot_20210430.pdf", vmax=2)
# Out:
# WARNING: saving figure to file figures/dotplotfigs11b_stroma_dotplot_20210430.pdf
# GridSpec(2, 5, height_ratios=[0, 10.5], width_ratios=[14.35, 0, 0.2, 0.5, 0.25])

# %% [markdown]
# # Save the data

# %%
from scipy.sparse import csr_matrix
adata.X = scipy.sparse.csr_matrix(adata.X)

# %%
adata.X
# Out:
# <3989x33712 sparse matrix of type '<class 'numpy.float32'>'
# 	with 9564710 stored elements in Compressed Sparse Row format>

# %%
adata.raw.X
# Out:
# <3989x33712 sparse matrix of type '<class 'numpy.float32'>'
# 	with 10517361 stored elements in Compressed Sparse Row format>

# %%
adata.write("/Users/b8058304/Documents/PhD_work/Coding/manuscript_figs_mk3/data/figs11b_cpdb_hsc_stroma_dotplots_20210430.h5ad")
