# %% [markdown]
# # Import packages and data

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import seaborn as sns
import scipy.stats
import anndata
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.axes._axes import _log as matplotlib_axes_logger
from scipy import sparse
matplotlib_axes_logger.setLevel('ERROR')
# Out:
# /Users/b8058304/.pyenv/versions/3.6.4/envs/py36/lib/python3.6/site-packages/anndata/_core/anndata.py:21: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import RangeIndex

# %%
sc.settings.verbosity = 1  # verbosity: errors (0), warnings (1), info (2), hints (3)
# Set up the plot config for viewing the annotation clearly.
sc.settings.set_figure_params(dpi=120, dpi_save=1000)
sc.logging.print_versions()
# Out:
# scanpy==1.4.4 anndata==0.7.1 umap==0.3.10 numpy==1.17.1 scipy==1.4.1 pandas==1.0.5 scikit-learn==0.22.2.post1 statsmodels==0.11.1 python-igraph==0.8.0 louvain==0.6.1

# %% [markdown]
# # Load FBM cells

# %%
adata = sc.read('/Users/b8058304/Documents/PhD_work/Coding/bm_plus_19pcw/data/bm_plus_19pcw_raw_dr_20201007.h5ad')

# %%
adata.raw = adata

# %%
cell_numbers = adata.obs.groupby(["cell.labels"]).apply(len)
cell_numbers
# Out:
# cell.labels
# CD4 T cell             327
# CD8 T cell             171
# CD14 monocyte         8763
# CD56 bright NK         449
# CMP                    425
#                       ...
# schwann cells            9
# sinusoidal EC          550
# stromal macrophage    1464
# tDC                    193
# tip EC                 362
# Length: 64, dtype: int64

# %%
lymphoid_celltypes = ['NK progenitor', 'CD56 bright NK', 'mature NK', 'ILC precursor']

# %%
adata = adata[adata.obs['cell.labels'].isin(lymphoid_celltypes)].copy()

# %%
cell_numbers = adata.obs.groupby(["cell.labels"]).apply(len)
cell_numbers
# Out:
# cell.labels
# CD56 bright NK    449
# ILC precursor      67
# NK progenitor      26
# mature NK         136
# dtype: int64

# %%
adata.shape
# Out:
# (678, 33712)

# %% [markdown]
# # Pre-process the dataset

# %%
# normalise count data 
sc.pp.normalize_total(adata)

# %%
# log the count data 
sc.pp.log1p(adata)

# %%
# find variable genes
sc.pp.highly_variable_genes(adata, min_mean=0.0125, max_mean=3, min_disp=0.5)

# %%
# scale the data 
sc.pp.scale(adata, max_value=10)

# %%
# scale the negative values in adata.X (which have been normalised, logged and scaled) to zero 
adata.X = np.where(adata.X < 0, 0, adata.X)

# %% [markdown]
# # Run dotplot

# %%
genes = ['PRSS57', 
'SOX4', 
'TOX',
'GZMK',
'XCL1',
'NKG7',
'PRF1',
'GZMH',
'FCGR3A',
'KLRB1',
'ZBTB16',
'KIT',
'AHR',
'RORC']

# %%
adata.obs["cell.labels"] = adata.obs["cell.labels"].cat.reorder_categories(['NK progenitor',
      'CD56 bright NK', 'mature NK', 'ILC precursor'])

# %%
sc.settings.set_figure_params(dpi=120, dpi_save=1000)
sc.pl.dotplot(adata, var_names=genes, groupby="cell.labels", use_raw=False, 
              save="figs2g_nk_ilc_dotplot_20210111.pdf")
# Out:
# WARNING: saving figure to file figures/dotplotfigs2g_nk_ilc_dotplot_20210111.pdf
# GridSpec(2, 5, height_ratios=[0, 10.5], width_ratios=[4.8999999999999995, 0, 0.2, 0.5, 0.25])

# %% [markdown]
# # Save the data

# %%
from scipy.sparse import csr_matrix
adata.X = sparse.csr_matrix(adata.X)

# %%
adata.X
# Out:
# <678x33712 sparse matrix of type '<class 'numpy.float32'>'
# 	with 1175956 stored elements in Compressed Sparse Row format>

# %%
adata.raw.X
# Out:
# <678x33712 sparse matrix of type '<class 'numpy.float32'>'
# 	with 1282391 stored elements in Compressed Sparse Row format>

# %%
adata.write("/Users/b8058304/Documents/PhD_work/Coding/manuscript_figs_mk2/data/figs2g_nk_ilc_dotplot_20210111.h5ad")
