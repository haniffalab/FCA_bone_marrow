# %% [markdown]
# # Import packages and data

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import seaborn as sns
import scipy.stats
import anndata
import matplotlib.pyplot as plt
import matplotlib as mpl
import rpy2

# %%
sc.settings.verbosity = 1  # verbosity: errors (0), warnings (1), info (2), hints (3)
# Set up the plot config for viewing the annotation clearly.
sc.settings.set_figure_params(dpi=120, dpi_save=1000)
sc.logging.print_versions()
# Out:
# scanpy==1.4.4 anndata==0.7.1 umap==0.3.10 numpy==1.17.1 scipy==1.4.1 pandas==0.23.4 scikit-learn==0.22.2.post1 statsmodels==0.11.1 python-igraph==0.8.0 louvain==0.6.1

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %% [markdown]
# # Save UMAP for Monocle3 from the processed dataset

# %%
adata = sc.read("/Users/b8058304/Documents/PhD_work/Coding/manuscript_figs/data/fig2e_neut_dr_20200615.h5ad")

# %%
# save the info on variable genes used in scanpy so these can be transferred to monocle
gene_df = adata.var

# %%
pd.DataFrame(adata.obsm["X_draw_graph_fa"]).to_csv("/Users/b8058304/Documents/PhD_work/Coding/manuscript_figs/resources_for_pipelines/neut_fdg_20200615.csv")

# %% [markdown]
# # Load the fetal BM B cells from the raw dataset

# %%
adata = sc.read("/Users/b8058304/Documents/PhD_work/Coding/bm_plus_19pcw/data/bm_plus_19pcw_raw_dr_20200414.h5ad")

# %%
adata.raw = adata

# %%
cell_numbers = adata.obs.groupby(["cell.labels"]).apply(len)
cell_numbers
# Out:
# cell.labels
# CD4 T                        327
# CD8 T                        171
# CD14 monocyte               8787
# CD56 bright NK               540
# CMP                          425
# DC1                           50
# DC2                          598
# DC3                          705
# DC precursor                 201
# EI macrophage                 92
# ELP                         1358
# GMP                         1285
# HSC                           92
# ILC precursor                 67
# Immature B cell             1998
# MEMP                          16
# MEP                          269
# MK                          1036
# MPP lymphoid                  34
# MPP myeloid 1                 46
# MPP myeloid 2                 46
# NKT                          137
# Naive B cell                1423
# Pre B progenitor           14234
# Pre pro B progenitor        5428
# Pro B progenitor            5530
# Treg                          62
# adipo-CAR                    359
# arteriolar fibroblast         84
# basophil                     139
# chondrocyte                   81
# early MK                    1665
# early erythroid             7534
# early osteoblast             291
# endosteal fibroblast          54
# eo/baso/mast precursor       175
# eosinophil                   325
# immature EC                   69
# late erythroid              4649
# mast cell                    648
# mature NK                    136
# mid erythroid              14408
# monocyte precursor          7946
# monocytoid macrophage        296
# muscle                       219
# muscle stem cell             255
# myelocyte                   3854
# myeloid DC progenitor         31
# myofibroblast                 78
# neut myeloid                4184
# neutrophil                  4516
# osteoblast                   375
# osteoblast precursor         463
# osteochondral precursor      191
# osteoclast                  1378
# pDC                          713
# pDC progenitor                23
# proliferating EC              26
# promyelocyte                1922
# schwann cells                  9
# sinusoidal EC                550
# stromal macrophage          1493
# tDC                          193
# tip EC                       363
# dtype: int64

# %%
myeloid_celltypes = ['HSC', 'MPP myeloid 1', 'MPP myeloid 2', 'CMP', 'GMP', 'neut myeloid', 'promyelocyte', 
                     'myelocyte', 'neutrophil']

# %%
adata = adata[adata.obs['cell.labels'].isin(myeloid_celltypes)].copy()

# %%
adata.obs['cell.labels'] = adata.obs['cell.labels'].replace(['MPP myeloid 1', 'MPP myeloid 2'], ['MPP myeloid', 'MPP myeloid'])

# %%
adata.obs["cell.labels"] = adata.obs["cell.labels"].astype("category")

# %%
adata.obs["cell.labels"] = adata.obs["cell.labels"].cat.reorder_categories(['HSC', 'MPP myeloid', 
        'CMP', 'GMP', 'neut myeloid', 'promyelocyte', 'myelocyte', 'neutrophil'])

# %%
cell_numbers = adata.obs.groupby(["cell.labels"]).apply(len)
cell_numbers
# Out:
# cell.labels
# HSC               92
# MPP myeloid       92
# CMP              425
# GMP             1285
# neut myeloid    4184
# promyelocyte    1922
# myelocyte       3854
# neutrophil      4516
# dtype: int64

# %%
adata.shape
# Out:
# (16370, 33712)

# %%
adata.var = gene_df

# %%
adata.shape
# Out:
# (16370, 33712)

# %% [markdown]
# # Convert to CDS

# %% [markdown]
# # Load rpy2 link

# %%
# convert anndata to sce
import anndata2ri
anndata2ri.activate()
# %load_ext rpy2.ipython

# %%
# %R d = as.data.frame( R.Version() )
# %R d = d['version.string']
# Out:
#                  version.string
# 1  R version 3.6.2 (2019-12-12)

# %%
# %%R
#
# library(scran)
# library(RColorBrewer)
# library(slingshot)
# library(monocle)
# library(gam)
# library(clusterExperiment)
# library(ggplot2)
# library(plyr)
# Out:
# R[write to console]: Loading required package: SingleCellExperiment
#
# R[write to console]: Loading required package: SummarizedExperiment
#
# R[write to console]: Loading required package: GenomicRanges
#
# R[write to console]: Loading required package: stats4
#
# R[write to console]: Loading required package: BiocGenerics
#
# R[write to console]: Loading required package: parallel
#
# R[write to console]:
# Attaching package: ‘BiocGenerics’
#
#
# R[write to console]: The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
#
# R[write to console]: The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# R[write to console]: The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colnames,
#     dirname, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, setdiff, sort, table, tapply,
#     union, unique, unsplit, which, which.max, which.min
#
#
# R[write to console]: Loading required package: S4Vectors
#
# R[write to console]:
# Attaching package: ‘S4Vectors’
#
#
# R[write to console]: The following object is masked from ‘package:base’:
#
#     expand.grid
#
#
# R[write to console]: Loading required package: IRanges
#
# R[write to console]: Loading required package: GenomeInfoDb
#
# R[write to console]: Loading required package: Biobase
#
# R[write to console]: Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# R[write to console]: Loading required package: DelayedArray
#
# R[write to console]: Loading required package: matrixStats
#
# R[write to console]:
# Attaching package: ‘matrixStats’
#
#
# R[write to console]: The following objects are masked from ‘package:Biobase’:
#
#     anyMissing, rowMedians
#
#
# R[write to console]: Loading required package: BiocParallel
#
# R[write to console]:
# Attaching package: ‘DelayedArray’
#
#
# R[write to console]: The following objects are masked from ‘package:matrixStats’:
#
#     colMaxs, colMins, colRanges, rowMaxs, rowMins, rowRanges
#
#
# R[write to console]: The following objects are masked from ‘package:base’:
#
#     aperm, apply, rowsum
#
#
# R[write to console]: Loading required package: princurve
#
# R[write to console]: Loading required package: Matrix
#
# R[write to console]:
# Attaching package: ‘Matrix’
#
#
# R[write to console]: The following object is masked from ‘package:S4Vectors’:
#
#     expand
#
#
# R[write to console]: Loading required package: ggplot2
#
# R[write to console]: Loading required package: VGAM
#
# R[write to console]: Loading required package: splines
#
# R[write to console]: Loading required package: DDRTree
#
# R[write to console]: Loading required package: irlba
#
# R[write to console]: Loading required package: foreach
#
# R[write to console]: Loaded gam 1.16.1
#
#
# R[write to console]:
# Attaching package: ‘gam’
#
#
# R[write to console]: The following object is masked from ‘package:VGAM’:
#
#     s
#
#
# R[write to console]: Warning:
# R[write to console]:  namespace ‘bigmemory’ is not available and has been replaced
# by .GlobalEnv when processing object ‘’
#
# R[write to console]: Warning:
# R[write to console]:  namespace ‘bigmemory’ is not available and has been replaced
# by .GlobalEnv when processing object ‘’
#
# R[write to console]:
# Attaching package: ‘plyr’
#
#
# R[write to console]: The following object is masked from ‘package:matrixStats’:
#
#     count
#
#
# R[write to console]: The following object is masked from ‘package:IRanges’:
#
#     desc
#
#
# R[write to console]: The following object is masked from ‘package:S4Vectors’:
#
#     rename

# %% [markdown]
# # Convert Scanpy object to CellDataSet object and prepare obj

# %%
# %%R -i adata
# adata
# Out:
# class: SingleCellExperiment
# dim: 33712 16370
# metadata(0):
# assays(1): X
# rownames(33712): RP11-34P13.3 RP11-34P13.7 ... CTB-58E17.2
#   RP5-1077H22.1
# rowData names(6): gene_ids.1 feature_types.1 ... dispersions
#   dispersions_norm
# colnames(16370):
#   F21_boneMarrow_CD45+_FCAImmP7179367_3prime_AACTGGTGTAAGTGTA
#   F21_boneMarrow_CD45+_FCAImmP7179367_3prime_ACGGCCAAGGATTCGG ...
#   TTTGGAGGTACGACAG-1-WSSS_F_BON8710643
#   TTTGGTTGTGGATCGA-1-WSSS_F_BON8710643
# colData names(18): cell.labels doublets ... sort.ids april_cell.labels
# reducedDimNames(3): X_orig_pca PCA UMAP
# spikeNames(0):
# altExpNames(0):

# %%
#Preprocessing for monocle
data_mat_mon = adata.X.T
var_mon=adata.var.copy()
obs_mon=adata.obs.copy()

# %%
var_mon
# Out:
#                       gene_ids-1  feature_types-1  highly_variable         means  dispersions  dispersions_norm
# RP11-34P13.3     ENSG00000243485  Gene Expression            False  7.197080e-06    -2.138626         -2.419419
# RP11-34P13.7     ENSG00000238009  Gene Expression            False  5.548362e-04     0.225749         -0.100161
# RP11-34P13.8     ENSG00000239945  Gene Expression            False  7.469582e-05    -0.426745         -0.740205
# RP11-34P13.9     ENSG00000241599  Gene Expression            False  1.000000e-12          NaN               NaN
# FO538757.3       ENSG00000279928  Gene Expression            False  2.508648e-04     0.770263          0.433962
# FO538757.2       ENSG00000279457  Gene Expression             True  2.826686e-01     1.763873          0.993099
# AP006222.2       ENSG00000228463  Gene Expression             True  4.001264e-02     1.075382          0.733259
# RP4-669L17.10    ENSG00000237094  Gene Expression            False  1.484911e-03     0.703171          0.368150
# RP5-857K21.4     ENSG00000230021  Gene Expression            False  3.525775e-04    -0.354094         -0.668940
# RP11-206L10.9    ENSG00000237491  Gene Expression            False  1.140861e-02     1.048226          0.706621
# FAM87B           ENSG00000177757  Gene Expression            False  1.845305e-04     0.169220         -0.155612
# LINC00115        ENSG00000225880  Gene Expression            False  9.045118e-03     0.874659          0.536366
# FAM41C           ENSG00000230368  Gene Expression            False  4.297984e-03     0.388242          0.059230
# RP11-54O7.16     ENSG00000272438  Gene Expression            False  9.739456e-05     0.466514          0.136009
# RP11-54O7.1      ENSG00000230699  Gene Expression            False  1.096348e-03    -0.609186         -0.919164
# RP11-54O7.2      ENSG00000241180  Gene Expression            False  6.517441e-05    -1.666426         -1.956229
# RP11-54O7.3      ENSG00000223764  Gene Expression            False  1.757698e-04    -0.892141         -1.196720
# SAMD11           ENSG00000187634  Gene Expression            False  1.118309e-03    -0.468423         -0.781088
# NOC2L            ENSG00000188976  Gene Expression            False  1.262827e-01     0.425588          0.095864
# KLHL17           ENSG00000187961  Gene Expression            False  7.682558e-03     0.360988          0.032497
# PLEKHN1          ENSG00000187583  Gene Expression            False  4.210179e-05    -0.372194         -0.686694
# PERM1            ENSG00000187642  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-54O7.17     ENSG00000272512  Gene Expression            False  4.298595e-05    -0.762182         -1.069240
# HES4             ENSG00000188290  Gene Expression            False  1.736460e-03     1.725840          1.371305
# ISG15            ENSG00000187608  Gene Expression             True  1.499492e-01     1.879223          1.521761
# RP11-54O7.11     ENSG00000224969  Gene Expression            False  2.522463e-04     0.316284         -0.011354
# AGRN             ENSG00000188157  Gene Expression            False  2.635433e-03    -0.821961         -1.127879
# C1orf159         ENSG00000131591  Gene Expression            False  1.287357e-02     0.825484          0.488130
# LINC01342        ENSG00000223823  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-465B22.8    ENSG00000272141  Gene Expression            False  1.120107e-04    -0.201741         -0.519494
# TTLL10-AS1       ENSG00000205231  Gene Expression            False  1.419470e-04    -1.191616         -1.490480
# TTLL10           ENSG00000162571  Gene Expression            False  4.870885e-04    -0.950709         -1.254170
# TNFRSF18         ENSG00000186891  Gene Expression            False  3.624588e-04    -0.104179         -0.423794
# TNFRSF4          ENSG00000186827  Gene Expression            False  2.390652e-03     1.675117          1.321550
# SDF4             ENSG00000078808  Gene Expression            False  1.659898e-01     0.744913          0.409095
# B3GALT6          ENSG00000176022  Gene Expression            False  1.520790e-02     0.523655          0.192059
# FAM132A          ENSG00000184163  Gene Expression            False  2.943766e-03     1.405463          1.057041
# RP5-902P8.12     ENSG00000260179  Gene Expression            False  8.210231e-05    -1.586247         -1.877581
# UBE2J2           ENSG00000160087  Gene Expression             True  1.058194e-01     1.197943          0.853481
# RP5-902P8.10     ENSG00000230415  Gene Expression            False  6.400863e-05    -0.269380         -0.585842
# SCNN1D           ENSG00000162572  Gene Expression            False  4.189480e-03     0.663752          0.329484
# ACAP3            ENSG00000131584  Gene Expression             True  8.027180e-02     1.411652          1.063112
# PUSL1            ENSG00000169972  Gene Expression             True  4.460451e-02     0.993503          0.652942
# CPSF3L           ENSG00000127054  Gene Expression             True  1.561370e-01     1.156495          0.812824
# CPTP             ENSG00000224051  Gene Expression             True  2.584189e-02     1.435553          1.086557
# TAS1R3           ENSG00000169962  Gene Expression            False  1.809257e-03     1.694723          1.340781
# DVL1             ENSG00000107404  Gene Expression            False  1.814876e-02     0.717859          0.382558
# MXRA8            ENSG00000162576  Gene Expression            False  1.008006e-03    -0.409536         -0.723324
# AURKAIP1         ENSG00000175756  Gene Expression            False  4.924321e-01     0.988278         -0.556872
# CCNL2            ENSG00000221978  Gene Expression             True  1.563085e-01     1.286637          0.940482
# MRPL20           ENSG00000242485  Gene Expression            False  3.618571e-01     0.610785         -1.311264
# RP4-758J18.13    ENSG00000272455  Gene Expression            False  6.167354e-04    -0.888002         -1.192660
# ANKRD65          ENSG00000235098  Gene Expression            False  2.496368e-05    -0.894870         -1.199397
# RP4-758J18.10    ENSG00000225285  Gene Expression            False  1.000000e-12          NaN               NaN
# VWA1             ENSG00000179403  Gene Expression            False  5.004274e-05    -0.882942         -1.187696
# ATAD3C           ENSG00000215915  Gene Expression            False  2.628132e-03    -0.407583         -0.721409
# ATAD3B           ENSG00000160072  Gene Expression            False  4.085146e-02     0.796664          0.459859
# ATAD3A           ENSG00000197785  Gene Expression            False  5.128122e-02     0.267211         -0.059491
# TMEM240          ENSG00000205090  Gene Expression            False  2.356080e-04    -0.488040         -0.800329
# SSU72            ENSG00000160075  Gene Expression            False  3.548262e-01     1.299853          0.065789
# RP5-832C2.5      ENSG00000215014  Gene Expression             True  1.654224e-02     1.502896          1.152615
# C1orf233         ENSG00000228594  Gene Expression             True  2.063967e-02     1.100967          0.758356
# RP11-345P4.9     ENSG00000272106  Gene Expression            False  1.229560e-02     1.145832          0.802364
# MIB2             ENSG00000197530  Gene Expression             True  4.457807e-02     1.404624          1.056218
# MMP23B           ENSG00000189409  Gene Expression            False  2.782915e-03     0.881508          0.543084
# CDK11B           ENSG00000248333  Gene Expression             True  1.579091e-01     1.041182          0.699711
# RP11-345P4.10    ENSG00000272004  Gene Expression            False  2.323828e-03     0.746728          0.410876
# SLC35E2B         ENSG00000189339  Gene Expression             True  9.219502e-02     1.308559          0.961986
# RP11-345P4.7     ENSG00000269737  Gene Expression            False  2.560745e-04    -0.657829         -0.966879
# CDK11A           ENSG00000008128  Gene Expression             True  9.111214e-02     1.099005          0.756431
# SLC35E2          ENSG00000215790  Gene Expression            False  6.643002e-03     0.577890          0.245260
# NADK             ENSG00000008130  Gene Expression             True  5.445266e-01     1.862985          1.191168
# GNB1             ENSG00000078369  Gene Expression            False  4.620108e-01     1.276032          0.018185
# RP1-140A9.1      ENSG00000231050  Gene Expression            False  6.579385e-04    -0.698382         -1.006658
# CALML6           ENSG00000169885  Gene Expression            False  9.623139e-05    -0.846985         -1.152426
# TMEM52           ENSG00000178821  Gene Expression            False  3.089407e-04    -0.683508         -0.992068
# CFAP74           ENSG00000142609  Gene Expression            False  2.446590e-04    -0.048542         -0.369219
# RP11-547D24.1    ENSG00000233542  Gene Expression            False  1.276161e-05    -1.565857         -1.857580
# GABRD            ENSG00000187730  Gene Expression            False  3.359219e-04    -1.613156         -1.903977
# PRKCZ            ENSG00000067606  Gene Expression             True  4.401959e-02     1.995643          1.635959
# RP5-892K4.1      ENSG00000271806  Gene Expression            False  3.876188e-03     1.452817          1.103491
# RP11-181G12.2    ENSG00000182873  Gene Expression            False  3.077901e-03     1.781079          1.425489
# FAAP20           ENSG00000162585  Gene Expression            False  4.378567e-01     1.341352          0.148721
# SKI              ENSG00000157933  Gene Expression             True  6.553563e-02     1.495710          1.145566
# MORN1            ENSG00000116151  Gene Expression            False  6.809366e-03     0.963251          0.623268
# RER1             ENSG00000157916  Gene Expression             True  2.424953e-01     0.982554          0.642202
# PEX10            ENSG00000157911  Gene Expression            False  1.785035e-02     0.081775         -0.241388
# PLCH2            ENSG00000149527  Gene Expression            False  1.053032e-05    -1.758040         -2.046096
# RP3-395M20.2     ENSG00000224387  Gene Expression            False  1.000000e-12          NaN               NaN
# RP3-395M20.3     ENSG00000229393  Gene Expression            False  1.000000e-12          NaN               NaN
# PANK4            ENSG00000157881  Gene Expression             True  2.996242e-02     1.230841          0.885751
# HES5             ENSG00000197921  Gene Expression            False  5.292419e-05    -0.696773         -1.005080
# RP3-395M20.12    ENSG00000272449  Gene Expression             True  2.393247e-02     1.349327          1.001976
# RP3-395M20.8     ENSG00000238164  Gene Expression             True  4.245108e-02     1.917279          1.559090
# TNFRSF14         ENSG00000157873  Gene Expression             True  2.078932e-01     1.871765          1.514445
# RP3-395M20.9     ENSG00000228037  Gene Expression            False  3.071161e-04    -0.514622         -0.826404
# FAM213B          ENSG00000157870  Gene Expression             True  1.390425e-02     1.393234          1.045045
# MMEL1            ENSG00000142606  Gene Expression            False  3.390262e-03     0.951362          0.611605
# TTC34            ENSG00000215912  Gene Expression            False  6.099803e-04    -0.543393         -0.854626
# LINC00982        ENSG00000177133  Gene Expression            False  2.202107e-04    -0.617686         -0.927502
# PRDM16           ENSG00000142611  Gene Expression            False  2.538142e-04    -0.874444         -1.179360
# RP1-163G9.2      ENSG00000226286  Gene Expression            False  1.000000e-12          NaN               NaN
# ARHGEF16         ENSG00000130762  Gene Expression            False  4.317585e-05    -0.902015         -1.206406
# RP11-168F9.2     ENSG00000272088  Gene Expression            False  1.000000e-12          NaN               NaN
# MEGF6            ENSG00000162591  Gene Expression             True  4.275540e-02     1.963441          1.604371
# RP11-46F15.2     ENSG00000238260  Gene Expression            False  6.478698e-04     0.565398          0.233007
# TPRG1L           ENSG00000158109  Gene Expression             True  1.061404e-01     1.759615          1.404435
# WRAP73           ENSG00000116213  Gene Expression             True  1.062588e-01     1.736325          1.381589
# TP73             ENSG00000078900  Gene Expression            False  1.278405e-03     1.577560          1.225854
# RP5-1092A11.5    ENSG00000227589  Gene Expression            False  3.647384e-04     1.683967          1.330230
# TP73-AS1         ENSG00000227372  Gene Expression            False  1.413320e-02     0.445670          0.115563
# CCDC27           ENSG00000162592  Gene Expression            False  1.000000e-12          NaN               NaN
# SMIM1            ENSG00000235169  Gene Expression            False  2.455079e-02     0.697852          0.362933
# LRRC47           ENSG00000130764  Gene Expression             True  6.548464e-02     0.867304          0.529151
# RP1-286D6.5      ENSG00000272153  Gene Expression            False  1.506082e-04     0.411498          0.082043
# CEP104           ENSG00000116198  Gene Expression             True  3.825814e-02     1.120370          0.777389
# DFFB             ENSG00000169598  Gene Expression            False  7.741918e-03     0.048487         -0.274041
# C1orf174         ENSG00000198912  Gene Expression            False  6.725327e-02     0.652414          0.318362
# LINC01134        ENSG00000236423  Gene Expression            False  1.359128e-03     0.644237          0.310341
# RP5-1166F10.1    ENSG00000235054  Gene Expression            False  1.000000e-12          NaN               NaN
# AJAP1            ENSG00000196581  Gene Expression            False  1.000000e-12          NaN               NaN
# NPHP4            ENSG00000131697  Gene Expression            False  9.760117e-03     0.782633          0.446096
# KCNAB2           ENSG00000069424  Gene Expression             True  2.637036e-01     1.288012          0.941832
# CHD5             ENSG00000116254  Gene Expression            False  5.987940e-04    -0.017845         -0.339107
# RPL22            ENSG00000116251  Gene Expression            False  2.301817e+00     1.855535         -0.629881
# RP1-120G22.11    ENSG00000226944  Gene Expression            False  1.000000e-12          NaN               NaN
# RNF207           ENSG00000158286  Gene Expression            False  1.538450e-04    -0.861599         -1.166761
# ICMT             ENSG00000116237  Gene Expression            False  3.865577e-02     0.298509         -0.028790
# LINC00337        ENSG00000225077  Gene Expression            False  2.882628e-04    -0.615463         -0.925321
# GPR153           ENSG00000158292  Gene Expression            False  6.578471e-04     0.564387          0.232015
# ACOT7            ENSG00000097021  Gene Expression            False  4.418477e-02     0.053031         -0.269583
# RP1-202O8.3      ENSG00000271746  Gene Expression            False  2.367824e-03    -0.333423         -0.648663
# HES2             ENSG00000069812  Gene Expression            False  7.321008e-04     0.099294         -0.224204
# ESPN             ENSG00000187017  Gene Expression            False  3.149007e-04     0.940740          0.601185
# TNFRSF25         ENSG00000215788  Gene Expression            False  3.883519e-03     0.016321         -0.305593
# PLEKHG5          ENSG00000171680  Gene Expression            False  3.669026e-05    -1.202852         -1.501502
# NOL9             ENSG00000162408  Gene Expression            False  3.901344e-02     0.604762          0.271620
# TAS1R1           ENSG00000173662  Gene Expression            False  1.000000e-12          NaN               NaN
# ZBTB48           ENSG00000204859  Gene Expression             True  7.732586e-02     1.614165          1.261760
# KLHL21           ENSG00000162413  Gene Expression             True  5.913250e-02     1.491742          1.141673
# PHF13            ENSG00000116273  Gene Expression             True  1.746600e-02     1.299356          0.952958
# THAP3            ENSG00000041988  Gene Expression            False  5.930034e-02     0.834257          0.496734
# DNAJC11          ENSG00000007923  Gene Expression            False  4.351038e-02     0.249020         -0.077335
# RP11-242F24.1    ENSG00000228750  Gene Expression            False  6.934979e-05    -0.326860         -0.642226
# RP11-312B8.1     ENSG00000237436  Gene Expression            False  1.185376e-03     0.516280          0.184825
# CAMTA1           ENSG00000171735  Gene Expression            False  1.810593e-01     0.384974          0.056025
# RP4-549F15.1     ENSG00000225126  Gene Expression            False  1.156515e-04    -0.739105         -1.046605
# RP11-338N10.3    ENSG00000269978  Gene Expression            False  1.000000e-12          NaN               NaN
# VAMP3            ENSG00000049245  Gene Expression             True  2.215710e-01     1.600353          1.248212
# PER3             ENSG00000049246  Gene Expression             True  1.361079e-02     1.495511          1.145371
# RP3-467L1.4      ENSG00000236266  Gene Expression            False  1.171673e-03     1.345352          0.998077
# UTS2             ENSG00000049247  Gene Expression            False  1.577613e-03     1.222892          0.877954
# TNFRSF9          ENSG00000049249  Gene Expression            False  8.507625e-03     1.403669          1.055281
# PARK7            ENSG00000116288  Gene Expression            False  5.962303e-01     0.571133         -1.530551
# ERRFI1           ENSG00000116285  Gene Expression            False  3.158627e-03     1.186691          0.842443
# RP11-431K24.1    ENSG00000238290  Gene Expression            False  2.473078e-04     0.171100         -0.153768
# RP11-431K24.4    ENSG00000233645  Gene Expression            False  1.236520e-04     0.084681         -0.238538
# SLC45A1          ENSG00000162426  Gene Expression            False  1.000000e-12          NaN               NaN
# RERE             ENSG00000142599  Gene Expression             True  1.442681e-01     1.477329          1.127536
# RP5-1115A15.1    ENSG00000232912  Gene Expression            False  1.466793e-03     2.202973          1.839333
# RP4-633I8.4      ENSG00000228423  Gene Expression            False  4.276133e-05    -1.620343         -1.911026
# ENO1             ENSG00000074800  Gene Expression            False  1.588444e+00     1.388041         -0.870984
# ENO1-AS1         ENSG00000230679  Gene Expression            False  5.812394e-03     1.292161          0.945901
# CA6              ENSG00000131686  Gene Expression            False  1.056898e-04    -1.327077         -1.623356
# SLC2A7           ENSG00000197241  Gene Expression            False  1.000000e-12          NaN               NaN
# SLC2A5           ENSG00000142583  Gene Expression             True  1.483683e-01     1.511566          1.161119
# GPR157           ENSG00000180758  Gene Expression            False  2.458699e-03     0.186923         -0.138247
# MIR34AHG         ENSG00000228526  Gene Expression            False  1.261915e-04    -1.267310         -1.564730
# RP3-510D11.2     ENSG00000234546  Gene Expression            False  1.092062e-04     0.057084         -0.265608
# H6PD             ENSG00000049239  Gene Expression             True  5.394062e-02     1.436330          1.087319
# SPSB1            ENSG00000171621  Gene Expression            False  7.828646e-04     0.267600         -0.059110
# SLC25A33         ENSG00000171612  Gene Expression             True  4.300388e-02     0.875938          0.537620
# TMEM201          ENSG00000188807  Gene Expression            False  1.232645e-02     0.344585          0.016407
# PIK3CD           ENSG00000171608  Gene Expression             True  2.544981e-01     1.705104          1.350964
# PIK3CD-AS1       ENSG00000179840  Gene Expression            False  1.120505e-02     0.998107          0.657458
# PIK3CD-AS2       ENSG00000231789  Gene Expression            False  1.444464e-03     0.202220         -0.123242
# CLSTN1           ENSG00000171603  Gene Expression            False  5.614763e-02     0.518404          0.186909
# AL357140.1       ENSG00000280113  Gene Expression            False  1.000000e-12          NaN               NaN
# CTNNBIP1         ENSG00000178585  Gene Expression             True  1.101304e-01     1.035321          0.693962
# RP11-84A14.5     ENSG00000223989  Gene Expression            False  6.742048e-06    -2.203938         -2.483485
# LZIC             ENSG00000162441  Gene Expression             True  1.491358e-01     1.179581          0.835469
# NMNAT1           ENSG00000173614  Gene Expression             True  4.160726e-02     1.410333          1.061818
# RBP7             ENSG00000162444  Gene Expression             True  7.033928e-01     1.909489          0.901659
# UBE4B            ENSG00000130939  Gene Expression             True  8.725276e-02     1.309273          0.962686
# KIF1B            ENSG00000054523  Gene Expression             True  2.332986e-01     1.652918          1.299774
# PGD              ENSG00000142657  Gene Expression            False  1.120208e+00     1.880525          0.410295
# RP4-736L20.3     ENSG00000271989  Gene Expression            False  5.482858e-05    -1.491553         -1.784694
# APITD1-CORT      ENSG00000251503  Gene Expression            False  3.255099e-03    -0.638973         -0.948382
# APITD1           ENSG00000175279  Gene Expression            False  2.229922e-02     0.147363         -0.177052
# CORT             ENSG00000241563  Gene Expression            False  2.987861e-04    -1.070607         -1.371780
# DFFA             ENSG00000160049  Gene Expression            False  6.241049e-02     0.346580          0.018364
# RP5-1113E3.3     ENSG00000203469  Gene Expression            False  1.000000e-12          NaN               NaN
# PEX14            ENSG00000142655  Gene Expression            False  2.322413e-02     0.371284          0.042597
# CASZ1            ENSG00000130940  Gene Expression            False  1.063243e-02     2.026645          1.666370
# RP4-734G22.3     ENSG00000272078  Gene Expression            False  1.000000e-12          NaN               NaN
# C1orf127         ENSG00000175262  Gene Expression            False  8.116236e-04    -0.531969         -0.843421
# TARDBP           ENSG00000120948  Gene Expression             True  2.167397e-01     0.994629          0.654046
# RP4-635E18.9     ENSG00000277726  Gene Expression            False  2.568617e-05    -1.537233         -1.829502
# MASP2            ENSG00000009724  Gene Expression            False  1.207201e-04    -0.498136         -0.810233
# RP4-635E18.8     ENSG00000271895  Gene Expression            False  9.919517e-04    -0.167002         -0.485418
# SRM              ENSG00000116649  Gene Expression            False  1.173679e-01     0.174226         -0.150701
# EXOSC10          ENSG00000171824  Gene Expression            False  8.160651e-02     0.489561          0.158616
# RP4-635E18.7     ENSG00000226849  Gene Expression            False  2.393449e-04    -0.945229         -1.248795
# RP4-635E18.6     ENSG00000230337  Gene Expression            False  2.004433e-03    -0.310351         -0.626031
# MTOR             ENSG00000198793  Gene Expression             True  4.250261e-02     0.935764          0.596305
# UBIAD1           ENSG00000120942  Gene Expression            False  2.297299e-02    -0.173330         -0.491625
# PTCHD2           ENSG00000204624  Gene Expression            False  9.765127e-05    -1.131804         -1.431810
# RP1-69M21.2      ENSG00000235643  Gene Expression            False  1.000000e-12          NaN               NaN
# FBXO2            ENSG00000116661  Gene Expression            False  1.037276e-03     2.414998          2.047312
# FBXO44           ENSG00000132879  Gene Expression            False  3.901219e-03     0.497245          0.166154
# FBXO6            ENSG00000116663  Gene Expression             True  2.426073e-02     0.876142          0.537821
# MAD2L2           ENSG00000116670  Gene Expression            False  1.110982e-01     0.580950          0.248261
# DRAXIN           ENSG00000162490  Gene Expression            False  2.800394e-03    -0.085169         -0.405147
# AGTRAP           ENSG00000177674  Gene Expression            False  7.069073e-01     1.468219          0.099734
# C1orf167         ENSG00000215910  Gene Expression            False  8.352045e-05    -0.389369         -0.703542
# MTHFR            ENSG00000177000  Gene Expression             True  4.297876e-02     1.120952          0.777959
# CLCN6            ENSG00000011021  Gene Expression             True  3.241682e-02     0.896262          0.557556
# NPPA-AS1         ENSG00000242349  Gene Expression            False  1.146013e-03     0.490175          0.159218
# NPPA             ENSG00000175206  Gene Expression            False  2.657818e-04     0.896409          0.557701
# KIAA2013         ENSG00000116685  Gene Expression             True  1.361810e-01     1.241419          0.896127
# PLOD1            ENSG00000083444  Gene Expression             True  1.008959e-01     1.629000          1.276312
# MFN2             ENSG00000116688  Gene Expression             True  1.508039e-01     1.585665          1.233804
# MIIP             ENSG00000116691  Gene Expression             True  2.629236e-01     1.811268          1.455102
# TNFRSF8          ENSG00000120949  Gene Expression             True  3.169425e-02     1.565618          1.214140
# TNFRSF1B         ENSG00000028137  Gene Expression             True  7.124182e-01     2.067487          1.188789
# VPS13D           ENSG00000048707  Gene Expression             True  7.278656e-02     1.331832          0.984815
# RP5-888M10.2     ENSG00000229484  Gene Expression            False  4.745834e-05    -0.896744         -1.201235
# DHRS3            ENSG00000162496  Gene Expression            False  7.811321e-03    -0.510881         -0.822735
# RP11-474O21.5    ENSG00000272482  Gene Expression            False  3.078439e-04     0.119958         -0.203933
# HNRNPCL1         ENSG00000179172  Gene Expression            False  7.005663e-04    -0.690663         -0.999086
# HNRNPCL3         ENSG00000277058  Gene Expression            False  6.376166e-05    -0.946841         -1.250376
# HNRNPCL2         ENSG00000275774  Gene Expression            False  1.974382e-04    -0.520049         -0.831728
# HNRNPCL4         ENSG00000179412  Gene Expression            False  1.000000e-12          NaN               NaN
# LRRC38           ENSG00000162494  Gene Expression            False  3.283891e-05    -0.620674         -0.930433
# RP4-597A16.2     ENSG00000259961  Gene Expression            False  1.000000e-12          NaN               NaN
# PDPN             ENSG00000162493  Gene Expression            False  9.012753e-05    -0.899106         -1.203552
# PRDM2            ENSG00000116731  Gene Expression             True  2.228698e-01     1.469345          1.119704
# KAZN             ENSG00000189337  Gene Expression             True  2.209973e-02     1.830549          1.474015
# TMEM51-AS1       ENSG00000175147  Gene Expression            False  1.725776e-04     1.038628          0.697206
# TMEM51           ENSG00000171729  Gene Expression            False  6.077536e-03    -0.110994         -0.430479
# C1orf195         ENSG00000204464  Gene Expression            False  5.751250e-05    -0.525358         -0.836936
# FHAD1            ENSG00000142621  Gene Expression            False  1.572602e-03    -0.213397         -0.530928
# RP3-467K16.2     ENSG00000233485  Gene Expression            False  4.777836e-04    -0.804183         -1.110440
# RP3-467K16.7     ENSG00000236045  Gene Expression            False  1.000000e-12          NaN               NaN
# RP3-467K16.4     ENSG00000228140  Gene Expression            False  9.869325e-04     0.612206          0.278921
# EFHD2            ENSG00000142634  Gene Expression            False  4.746561e-01     1.455675          0.377188
# CTRC             ENSG00000162438  Gene Expression            False  2.065035e-04     0.386863          0.057878
# CELA2A           ENSG00000142615  Gene Expression            False  3.220173e-05    -1.056392         -1.357836
# CELA2B           ENSG00000215704  Gene Expression            False  5.282877e-05    -0.145223         -0.464054
# CASP9            ENSG00000132906  Gene Expression            False  2.514420e-02     0.693417          0.358583
# ...                          ...              ...              ...           ...          ...               ...
# FGF6             ENSG00000111241  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-529K1.3     ENSG00000260537  Gene Expression            False  1.000000e-12          NaN               NaN
# CRAT40           ENSG00000263520  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-388P9.3     ENSG00000282121  Gene Expression            False  1.000000e-12          NaN               NaN
# AC007557.3       ENSG00000227021  Gene Expression            False  1.000000e-12          NaN               NaN
# NT5C1A           ENSG00000116981  Gene Expression            False  1.000000e-12          NaN               NaN
# AADACL4          ENSG00000204518  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-665J16.1    ENSG00000261543  Gene Expression            False  1.000000e-12          NaN               NaN
# AP002856.5       ENSG00000231698  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-565N2.2     ENSG00000259815  Gene Expression            False  1.000000e-12          NaN               NaN
# AC007392.4       ENSG00000237179  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-274H2.2     ENSG00000243415  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-122M14.3    ENSG00000226868  Gene Expression            False  1.000000e-12          NaN               NaN
# RP5-998H6.2      ENSG00000229957  Gene Expression            False  1.000000e-12          NaN               NaN
# ATRIP-1          ENSG00000164053  Gene Expression            False  7.956891e-04     1.885629          1.528044
# WI2-8325B5.1     ENSG00000276786  Gene Expression            False  1.000000e-12          NaN               NaN
# LINC01586        ENSG00000249487  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-80I3.1      ENSG00000276759  Gene Expression            False  1.000000e-12          NaN               NaN
# SI               ENSG00000090402  Gene Expression            False  1.000000e-12          NaN               NaN
# SPATA3-AS1       ENSG00000238062  Gene Expression            False  1.000000e-12          NaN               NaN
# RP1-138B7.5      ENSG00000226143  Gene Expression            False  1.000000e-12          NaN               NaN
# AP000146.2       ENSG00000230379  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-722M1.1     ENSG00000248215  Gene Expression            False  1.000000e-12          NaN               NaN
# IGKV3D-34        ENSG00000253501  Gene Expression            False  1.000000e-12          NaN               NaN
# IGHV3OR16-12     ENSG00000270467  Gene Expression            False  1.000000e-12          NaN               NaN
# AC093590.1       ENSG00000238217  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-624G17.3    ENSG00000255301  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-397O8.7     ENSG00000276012  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-65D17.1     ENSG00000244791  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-133L19.1    ENSG00000259620  Gene Expression            False  1.000000e-12          NaN               NaN
# IGLVIV-66-1      ENSG00000253874  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-728E14.2    ENSG00000264023  Gene Expression            False  1.000000e-12          NaN               NaN
# LINC00349        ENSG00000231238  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-386M24.10   ENSG00000275965  Gene Expression            False  1.000000e-12          NaN               NaN
# IQCA1-AS1        ENSG00000232893  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-793B23.1    ENSG00000250034  Gene Expression            False  1.000000e-12          NaN               NaN
# ARHGEF7-AS2      ENSG00000235875  Gene Expression            False  1.000000e-12          NaN               NaN
# CTD-2659N19.4    ENSG00000267004  Gene Expression            False  1.000000e-12          NaN               NaN
# CT47A2           ENSG00000242362  Gene Expression            False  1.000000e-12          NaN               NaN
# C3orf36          ENSG00000221972  Gene Expression            False  1.000000e-12          NaN               NaN
# AC062021.1       ENSG00000226939  Gene Expression            False  1.000000e-12          NaN               NaN
# AC069257.8       ENSG00000228028  Gene Expression            False  9.183778e-05     0.407765          0.078381
# RP11-94B19.6     ENSG00000266743  Gene Expression            False  1.000000e-12          NaN               NaN
# CT45A10          ENSG00000269586  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-71J4.2      ENSG00000256273  Gene Expression            False  1.000000e-12          NaN               NaN
# MUC22            ENSG00000261272  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-142J21.1    ENSG00000259360  Gene Expression            False  1.000000e-12          NaN               NaN
# AC009312.1       ENSG00000238207  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-113D6.6     ENSG00000255470  Gene Expression            False  1.000000e-12          NaN               NaN
# IL21             ENSG00000138684  Gene Expression            False  1.000000e-12          NaN               NaN
# CTD-2526M8.2     ENSG00000267726  Gene Expression            False  1.000000e-12          NaN               NaN
# LAMA5-AS1        ENSG00000228812  Gene Expression            False  1.000000e-12          NaN               NaN
# LRRC72           ENSG00000205858  Gene Expression            False  1.000000e-12          NaN               NaN
# AC006019.3       ENSG00000203335  Gene Expression            False  1.000000e-12          NaN               NaN
# CTD-2013M15.1    ENSG00000250122  Gene Expression            False  1.000000e-12          NaN               NaN
# TRAJ59           ENSG00000211832  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-208N20.1    ENSG00000250141  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-328K22.1    ENSG00000224500  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-98J9.2      ENSG00000254927  Gene Expression            False  1.000000e-12          NaN               NaN
# LINC00408        ENSG00000226250  Gene Expression            False  1.000000e-12          NaN               NaN
# AF186192.1       ENSG00000254533  Gene Expression            False  1.000000e-12          NaN               NaN
# AC006150.1       ENSG00000226323  Gene Expression            False  1.000000e-12          NaN               NaN
# AC007422.1       ENSG00000224173  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-348B17.1    ENSG00000259720  Gene Expression            False  1.000000e-12          NaN               NaN
# AC005281.1       ENSG00000226690  Gene Expression            False  1.000000e-12          NaN               NaN
# RP13-221M14.2    ENSG00000233336  Gene Expression            False  1.000000e-12          NaN               NaN
# OTX2             ENSG00000165588  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-506D12.5    ENSG00000261976  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-699F16.2    ENSG00000255187  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-277J6.3     ENSG00000265935  Gene Expression            False  1.000000e-12          NaN               NaN
# OR4D11           ENSG00000176200  Gene Expression            False  1.000000e-12          NaN               NaN
# LINC01384        ENSG00000237396  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-79E3.3      ENSG00000250954  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-324D17.3    ENSG00000275147  Gene Expression            False  1.000000e-12          NaN               NaN
# MYCNUT           ENSG00000223850  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-255G12.2    ENSG00000258942  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-30L8.1      ENSG00000232252  Gene Expression            False  1.000000e-12          NaN               NaN
# AC106874.1       ENSG00000228272  Gene Expression            False  1.000000e-12          NaN               NaN
# EFCAB6-AS1       ENSG00000223843  Gene Expression            False  1.000000e-12          NaN               NaN
# RP4-543J13.1     ENSG00000232895  Gene Expression            False  1.000000e-12          NaN               NaN
# IGKV2-4          ENSG00000253435  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-347J14.8    ENSG00000224038  Gene Expression            False  1.000000e-12          NaN               NaN
# IGHV3-25         ENSG00000253441  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-154H17.1    ENSG00000236948  Gene Expression            False  1.000000e-12          NaN               NaN
# LINC01248        ENSG00000224128  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-2K6.2       ENSG00000261743  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-346C4.3     ENSG00000274718  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-89K21.1     ENSG00000259439  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-556I13.2    ENSG00000268170  Gene Expression            False  1.000000e-12          NaN               NaN
# C11orf88         ENSG00000183644  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-253D19.2    ENSG00000230298  Gene Expression            False  1.000000e-12          NaN               NaN
# ODF3             ENSG00000177947  Gene Expression            False  1.000000e-12          NaN               NaN
# LINC01177        ENSG00000261397  Gene Expression            False  1.000000e-12          NaN               NaN
# ZIC3             ENSG00000156925  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-863K10.2    ENSG00000253181  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-237D3.1     ENSG00000251490  Gene Expression            False  1.000000e-12          NaN               NaN
# PCDHA9           ENSG00000204961  Gene Expression            False  1.000000e-12          NaN               NaN
# OR10J1           ENSG00000196184  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-258B16.1    ENSG00000267642  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-510C10.2    ENSG00000224127  Gene Expression            False  1.000000e-12          NaN               NaN
# CTD-2349B8.1     ENSG00000261427  Gene Expression            False  1.000000e-12          NaN               NaN
# DMRTC1           ENSG00000269502  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-669M2.1     ENSG00000225006  Gene Expression            False  1.000000e-12          NaN               NaN
# RP1-128O3.4      ENSG00000230248  Gene Expression            False  1.000000e-12          NaN               NaN
# CCR8             ENSG00000179934  Gene Expression            False  1.000000e-12          NaN               NaN
# CTD-2515H24.3    ENSG00000261489  Gene Expression            False  1.000000e-12          NaN               NaN
# OR13D1           ENSG00000179055  Gene Expression            False  1.000000e-12          NaN               NaN
# AC145123.2       ENSG00000277332  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-460B17.2    ENSG00000255227  Gene Expression            False  1.000000e-12          NaN               NaN
# CTD-2089N3.2     ENSG00000251573  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-528N21.1    ENSG00000226302  Gene Expression            False  1.000000e-12          NaN               NaN
# KRT35            ENSG00000197079  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-44L9.3      ENSG00000259971  Gene Expression            False  1.000000e-12          NaN               NaN
# XXyac-YM21GA2.4  ENSG00000234460  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-363L24.3    ENSG00000253961  Gene Expression            False  1.000000e-12          NaN               NaN
# PLCE1-AS1        ENSG00000268894  Gene Expression            False  1.000000e-12          NaN               NaN
# OR5M1            ENSG00000255012  Gene Expression            False  1.000000e-12          NaN               NaN
# RP4-639J15.1     ENSG00000236102  Gene Expression            False  1.000000e-12          NaN               NaN
# NLGN1-AS1        ENSG00000228213  Gene Expression            False  1.000000e-12          NaN               NaN
# DBX2             ENSG00000185610  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-254I22.2    ENSG00000250158  Gene Expression            False  1.000000e-12          NaN               NaN
# ABCG8            ENSG00000143921  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-66A2.1      ENSG00000225919  Gene Expression            False  1.000000e-12          NaN               NaN
# CTA-125H2.1      ENSG00000232464  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-402G3.3     ENSG00000230601  Gene Expression            False  1.000000e-12          NaN               NaN
# AC079150.3       ENSG00000227708  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-159M11.2    ENSG00000237993  Gene Expression            False  9.143596e-05     0.248375         -0.077968
# RP11-544M22.8    ENSG00000228917  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-178F10.3    ENSG00000266489  Gene Expression            False  1.000000e-12          NaN               NaN
# TRBJ1-5          ENSG00000282173  Gene Expression            False  1.000000e-12          NaN               NaN
# TRAJ25           ENSG00000211864  Gene Expression            False  1.000000e-12          NaN               NaN
# LINC01312        ENSG00000223586  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-319G6.3     ENSG00000248790  Gene Expression            False  1.000000e-12          NaN               NaN
# AC092570.2       ENSG00000223826  Gene Expression            False  1.000000e-12          NaN               NaN
# TRAJ31           ENSG00000211858  Gene Expression            False  1.000000e-12          NaN               NaN
# RP5-994D16.9     ENSG00000228452  Gene Expression            False  1.000000e-12          NaN               NaN
# CCDC70           ENSG00000123171  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-494G9.1     ENSG00000276411  Gene Expression            False  1.000000e-12          NaN               NaN
# KRT78            ENSG00000170423  Gene Expression            False  1.000000e-12          NaN               NaN
# OR10R2           ENSG00000198965  Gene Expression            False  1.000000e-12          NaN               NaN
# PASD1            ENSG00000166049  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-716H6.2     ENSG00000255219  Gene Expression            False  1.000000e-12          NaN               NaN
# TRBV22OR9-2      ENSG00000234122  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-579E24.2    ENSG00000253762  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-155L15.1    ENSG00000249697  Gene Expression            False  1.000000e-12          NaN               NaN
# FGF12-AS3        ENSG00000226709  Gene Expression            False  1.000000e-12          NaN               NaN
# TRBV5-3          ENSG00000211715  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-248E9.5     ENSG00000257912  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-386M24.9    ENSG00000271763  Gene Expression            False  1.000000e-12          NaN               NaN
# CTC-268N12.2     ENSG00000278638  Gene Expression            False  1.000000e-12          NaN               NaN
# LINC00353        ENSG00000236176  Gene Expression            False  1.000000e-12          NaN               NaN
# CTD-2012M11.3    ENSG00000259603  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-385J1.3     ENSG00000275163  Gene Expression            False  1.000000e-12          NaN               NaN
# S100G            ENSG00000169906  Gene Expression            False  1.000000e-12          NaN               NaN
# ANXA10           ENSG00000109511  Gene Expression            False  1.000000e-12          NaN               NaN
# GALNT13          ENSG00000144278  Gene Expression            False  1.000000e-12          NaN               NaN
# OR8B4            ENSG00000198657  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-488C13.7    ENSG00000258610  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-88I21.2     ENSG00000244215  Gene Expression            False  8.376363e-05     0.315736         -0.011892
# KRTAP29-1        ENSG00000212658  Gene Expression            False  1.000000e-12          NaN               NaN
# AC073094.4       ENSG00000233082  Gene Expression            False  1.000000e-12          NaN               NaN
# SPAG11B          ENSG00000164871  Gene Expression            False  1.000000e-12          NaN               NaN
# C1QL2            ENSG00000144119  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-305P22.9    ENSG00000272259  Gene Expression            False  1.000000e-12          NaN               NaN
# AC018799.1       ENSG00000225539  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-554D14.8    ENSG00000274395  Gene Expression            False  1.000000e-12          NaN               NaN
# AC022173.2       ENSG00000237243  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-281H11.1    ENSG00000254007  Gene Expression            False  1.000000e-12          NaN               NaN
# LINC00355        ENSG00000227674  Gene Expression            False  1.000000e-12          NaN               NaN
# AJ003147.8       ENSG00000262521  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-1437A8.4    ENSG00000260827  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-286N3.1     ENSG00000265316  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-706F1.2     ENSG00000249877  Gene Expression            False  1.000000e-12          NaN               NaN
# ALDH1L1-AS2      ENSG00000246022  Gene Expression            False  1.000000e-12          NaN               NaN
# LINC00370        ENSG00000223617  Gene Expression            False  1.845538e-04     1.105728          0.763026
# RP11-491F9.8     ENSG00000259957  Gene Expression            False  1.000000e-12          NaN               NaN
# AC107081.1       ENSG00000280544  Gene Expression            False  1.000000e-12          NaN               NaN
# RBP2             ENSG00000114113  Gene Expression            False  1.000000e-12          NaN               NaN
# LINC01360        ENSG00000233973  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-453O5.1     ENSG00000249547  Gene Expression            False  1.000000e-12          NaN               NaN
# MBD3L2           ENSG00000230522  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-32K4.1      ENSG00000253554  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-410C4.4     ENSG00000231529  Gene Expression            False  1.000000e-12          NaN               NaN
# MIR5689HG        ENSG00000229401  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-753D20.4    ENSG00000259998  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-628O18.1    ENSG00000263684  Gene Expression            False  1.000000e-12          NaN               NaN
# RP4-811H24.9     ENSG00000233775  Gene Expression            False  1.000000e-12          NaN               NaN
# RP1-102D24.5     ENSG00000232363  Gene Expression            False  1.000000e-12          NaN               NaN
# KRTAP3-1         ENSG00000212901  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-407A16.7    ENSG00000255998  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-128P10.1    ENSG00000257579  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-655G22.1    ENSG00000232353  Gene Expression            False  1.000000e-12          NaN               NaN
# TBC1D3E          ENSG00000278599  Gene Expression            False  1.000000e-12          NaN               NaN
# AP000997.1       ENSG00000255599  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-812E19.3    ENSG00000205452  Gene Expression            False  1.000000e-12          NaN               NaN
# PPAN-P2RY11      ENSG00000243207  Gene Expression            False  1.000000e-12          NaN               NaN
# LINC01179        ENSG00000249500  Gene Expression            False  1.000000e-12          NaN               NaN
# CTD-3187F8.2     ENSG00000268595  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-849I19.1    ENSG00000263146  Gene Expression            False  1.000000e-12          NaN               NaN
# CTD-2135J3.4     ENSG00000258724  Gene Expression            False  1.000000e-12          NaN               NaN
# RP4-791M13.4     ENSG00000255148  Gene Expression            False  1.000000e-12          NaN               NaN
# LINC01035        ENSG00000226486  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-465K16.1    ENSG00000254383  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-298O21.6    ENSG00000242924  Gene Expression            False  1.000000e-12          NaN               NaN
# DEFB133          ENSG00000214643  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-99J16__A.2  ENSG00000244137  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-96L7.2      ENSG00000227269  Gene Expression            False  1.000000e-12          NaN               NaN
# CTRB1            ENSG00000168925  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-474B16.1    ENSG00000257642  Gene Expression            False  1.000000e-12          NaN               NaN
# IGHD6-6          ENSG00000228131  Gene Expression            False  1.000000e-12          NaN               NaN
# PLCH1-AS2        ENSG00000242925  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-357K6.1     ENSG00000255618  Gene Expression            False  1.000000e-12          NaN               NaN
# LINC01596        ENSG00000250666  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-414H23.3    ENSG00000251093  Gene Expression            False  1.000000e-12          NaN               NaN
# SLC5A8           ENSG00000256870  Gene Expression            False  1.000000e-12          NaN               NaN
# AC017006.3       ENSG00000231336  Gene Expression            False  1.000000e-12          NaN               NaN
# AC005387.3       ENSG00000268938  Gene Expression            False  1.000000e-12          NaN               NaN
# RP13-57D9.3      ENSG00000228160  Gene Expression            False  1.000000e-12          NaN               NaN
# PCYT1B-AS1       ENSG00000236836  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-664H17.1    ENSG00000256287  Gene Expression            False  1.000000e-12          NaN               NaN
# AC018804.3       ENSG00000224087  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-308K2.1     ENSG00000249747  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-558A11.1    ENSG00000260858  Gene Expression            False  1.000000e-12          NaN               NaN
# IGHVIII-25-1     ENSG00000253367  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-123O10.4    ENSG00000256248  Gene Expression            False  1.000000e-12          NaN               NaN
# CLCA4            ENSG00000016602  Gene Expression            False  1.000000e-12          NaN               NaN
# RP1-209A6.1      ENSG00000233358  Gene Expression            False  1.000000e-12          NaN               NaN
# AC004448.2       ENSG00000227078  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-510M2.1     ENSG00000261348  Gene Expression            False  1.000000e-12          NaN               NaN
# SLC22A12         ENSG00000197891  Gene Expression            False  1.000000e-12          NaN               NaN
# AC005863.2       ENSG00000238212  Gene Expression            False  1.000000e-12          NaN               NaN
# FOXL2NB          ENSG00000206262  Gene Expression            False  9.178370e-06    -1.895451         -2.180884
# RP11-87N24.3     ENSG00000232035  Gene Expression            False  1.000000e-12          NaN               NaN
# SRGAP3-AS1       ENSG00000224808  Gene Expression            False  1.000000e-12          NaN               NaN
# CTD-2540B15.12   ENSG00000270212  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-240B13.2    ENSG00000258417  Gene Expression            False  1.000000e-12          NaN               NaN
# LINC01392        ENSG00000233607  Gene Expression            False  1.000000e-12          NaN               NaN
# AC004054.1       ENSG00000248984  Gene Expression            False  1.000000e-12          NaN               NaN
# AC004485.3       ENSG00000228944  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-452D21.1    ENSG00000258426  Gene Expression            False  1.000000e-12          NaN               NaN
# CTD-2313F11.3    ENSG00000248029  Gene Expression            False  1.000000e-12          NaN               NaN
# TTTY3B           ENSG00000280961  Gene Expression            False  1.000000e-12          NaN               NaN
# DLGAP1-AS5       ENSG00000261520  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-679B17.2    ENSG00000271897  Gene Expression            False  1.000000e-12          NaN               NaN
# RP11-373J21.1    ENSG00000250877  Gene Expression            False  1.000000e-12          NaN               NaN
# TRBJ2-2          ENSG00000211765  Gene Expression            False  1.000000e-12          NaN               NaN
# MAGEA2           ENSG00000268606  Gene Expression            False  1.000000e-12          NaN               NaN
# CTD-2308B18.4    ENSG00000248600  Gene Expression            False  1.000000e-12          NaN               NaN
# CTB-58E17.2      ENSG00000274996  Gene Expression            False  1.000000e-12          NaN               NaN
# RP5-1077H22.1    ENSG00000278343  Gene Expression            False  1.000000e-12          NaN               NaN
#
# [33712 rows x 6 columns]

# %%
# %%R -i data_mat_mon -i obs_mon -i var_mon
#
# #Set up the CellDataSet data structure
# print("setting up cell dataset structure")
# print("printing pd - cells")
# pd <- AnnotatedDataFrame(data = obs_mon)
# print(pd)
# print("printing fd - genes")
# fd <- AnnotatedDataFrame(data = var_mon)
# print(fd)
# # assigning cells as column name and genes as rownames of GEX matrix (data_mat_mon)
# colnames(data_mat_mon) <- rownames(pd)
# rownames(data_mat_mon) <- rownames(fd)
# print("create newCellDataSet using the matrix, cells and genes")
# ie_regions_cds <- newCellDataSet(cellData=data_mat_mon, phenoData=pd, featureData=fd, expressionFamily=negbinomial.size())
#
# # print ie_regions_cds
# print("printing ie_regions_cds")
# print(ie_regions_cds)
# Out:
# [1] "setting up cell dataset structure"
# [1] "printing pd - cells"
# An object of class 'AnnotatedDataFrame'
#   rowNames: F21_boneMarrow_CD45+_FCAImmP7179367_3prime_AACTGGTGTAAGTGTA
#     F21_boneMarrow_CD45+_FCAImmP7179367_3prime_ACGGCCAAGGATTCGG ...
#     TTTGGTTGTGGATCGA-1-WSSS_F_BON8710643 (16370 total)
#   varLabels: cell.labels doublets ... april_cell.labels (18 total)
#   varMetadata: labelDescription
# [1] "printing fd - genes"
# An object of class 'AnnotatedDataFrame'
#   rowNames: RP11-34P13.3 RP11-34P13.7 ... RP5-1077H22.1 (33712 total)
#   varLabels: gene_ids.1 feature_types.1 ... dispersions_norm (6 total)
#   varMetadata: labelDescription
# [1] "create newCellDataSet using the matrix, cells and genes"
# [1] "printing ie_regions_cds"
# CellDataSet (storageMode: environment)
# assayData: 33712 features, 16370 samples
#   element names: exprs
# protocolData: none
# phenoData
#   sampleNames:
#     F21_boneMarrow_CD45+_FCAImmP7179367_3prime_AACTGGTGTAAGTGTA
#     F21_boneMarrow_CD45+_FCAImmP7179367_3prime_ACGGCCAAGGATTCGG ...
#     TTTGGTTGTGGATCGA-1-WSSS_F_BON8710643 (16370 total)
#   varLabels: cell.labels doublets ... Size_Factor (19 total)
#   varMetadata: labelDescription
# featureData
#   featureNames: RP11-34P13.3 RP11-34P13.7 ... RP5-1077H22.1 (33712
#     total)
#   fvarLabels: gene_ids.1 feature_types.1 ... dispersions_norm (6 total)
#   fvarMetadata: labelDescription
# experimentData: use 'experimentData(object)'
# Annotation:

# %% [markdown]
# # Within CDS, select HVGs (previously defined in scanpy)

# %%
# %%R
#
# #Filter highly variable genes from our analysis (normalisation by log and size factor will be performed in monocle3)
# print("filter hvgs")
# hvg_mask = fData(ie_regions_cds)$highly_variable
# ie_regions_cds <- ie_regions_cds[hvg_mask,]
#
# # print ie_regions_cds
# print("printing cds again")
# print(ie_regions_cds)
# Out:
# [1] "filter hvgs"
# [1] "printing cds again"
# CellDataSet (storageMode: environment)
# assayData: 5797 features, 16370 samples
#   element names: exprs
# protocolData: none
# phenoData
#   sampleNames:
#     F21_boneMarrow_CD45+_FCAImmP7179367_3prime_AACTGGTGTAAGTGTA
#     F21_boneMarrow_CD45+_FCAImmP7179367_3prime_ACGGCCAAGGATTCGG ...
#     TTTGGTTGTGGATCGA-1-WSSS_F_BON8710643 (16370 total)
#   varLabels: cell.labels doublets ... Size_Factor (19 total)
#   varMetadata: labelDescription
# featureData
#   featureNames: FO538757.2 AP006222.2 ... AC004556.1 (5797 total)
#   fvarLabels: gene_ids.1 feature_types.1 ... dispersions_norm (6 total)
#   fvarMetadata: labelDescription
# experimentData: use 'experimentData(object)'
# Annotation:

# %% [markdown]
# # Save object for input into Monocle3

# %%
# %%R
#
# saveRDS(ie_regions_cds,
#         "/Users/b8058304/Documents/PhD_work/Coding/manuscript_figs/data/fig2e_neut_cds_20200615.RDS")
