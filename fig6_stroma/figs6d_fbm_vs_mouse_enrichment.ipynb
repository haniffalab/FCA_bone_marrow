# %% [markdown]
# # Import packages and data

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import seaborn as sns
import scipy.stats
import anndata
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.axes._axes import _log as matplotlib_axes_logger
from scipy import sparse
matplotlib_axes_logger.setLevel('ERROR')
# silence NumbaPerformanceWarning
import warnings
from numba.errors import NumbaPerformanceWarning
warnings.filterwarnings("ignore", category=NumbaPerformanceWarning)
# Out:
# /Users/b8058304/.pyenv/versions/3.6.4/envs/py36/lib/python3.6/site-packages/anndata/_core/anndata.py:21: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import RangeIndex

# %%
sc.settings.verbosity = 1  # verbosity: errors (0), warnings (1), info (2), hints (3)
# Set up the plot config for viewing the annotation clearly.
sc.settings.set_figure_params(dpi=120, dpi_save=1000)
sc.logging.print_versions()
# Out:
# scanpy==1.4.4 anndata==0.7.1 umap==0.3.10 numpy==1.18.1 scipy==1.4.1 pandas==1.0.2 scikit-learn==0.22.2.post1 statsmodels==0.11.1 python-igraph==0.8.0 louvain==0.6.1

# %% [markdown]
# # Load FBM stroma

# %%
adata = sc.read('/Users/b8058304/Documents/PhD_work/Coding/bm_plus_19pcw/data/bm_plus_19pcw_raw_dr_20200414.h5ad')

# %%
adata.raw = adata

# %%
cell_numbers = adata.obs.groupby(["cell.labels"]).apply(len)
cell_numbers
# Out:
# cell.labels
# CD4 T                  327
# CD8 T                  171
# CD14 monocyte         8787
# CD56 bright NK         540
# CMP                    425
#                       ...
# schwann cells            9
# sinusoidal EC          550
# stromal macrophage    1493
# tDC                    193
# tip EC                 363
# Length: 64, dtype: int64

# %%
adata = adata[adata.obs['cell.labels'].isin(['adipo-CAR', 'arteriolar fibroblast', 'tip EC', 'stromal macrophage', 
                                             'sinusoidal EC', 
                      'schwann cells', 'proliferating EC', 'osteoclast', 'osteochondral precursor', 
                      'osteoblast precursor',                                        
                     'osteoblast', 'myofibroblast', 'muscle stem cell', 'muscle', 'monocytoid macrophage',  
                     'EI macrophage', 'immature EC', 'endosteal fibroblast', 'early osteoblast', 'chondrocyte'])].copy()

# %%
cell_numbers = adata.obs.groupby(["cell.labels"]).apply(len)
cell_numbers
# Out:
# cell.labels
# EI macrophage                92
# adipo-CAR                   359
# arteriolar fibroblast        84
# chondrocyte                  81
# early osteoblast            291
# endosteal fibroblast         54
# immature EC                  69
# monocytoid macrophage       296
# muscle                      219
# muscle stem cell            255
# myofibroblast                78
# osteoblast                  375
# osteoblast precursor        463
# osteochondral precursor     191
# osteoclast                 1378
# proliferating EC             26
# schwann cells                 9
# sinusoidal EC               550
# stromal macrophage         1493
# tip EC                      363
# dtype: int64

# %%
adata.obs["cell.labels_broad"] = adata.obs["cell.labels"]
adata.obs["cell.labels"] = adata.obs["cell.labels"].replace(["muscle stem cell"], ["muscle"])

# %%
cell_numbers = adata.obs.groupby(["cell.labels"]).apply(len)
cell_numbers
# Out:
# cell.labels
# EI macrophage                92
# adipo-CAR                   359
# arteriolar fibroblast        84
# chondrocyte                  81
# early osteoblast            291
# endosteal fibroblast         54
# immature EC                  69
# monocytoid macrophage       296
# muscle                      474
# myofibroblast                78
# osteoblast                  375
# osteoblast precursor        463
# osteochondral precursor     191
# osteoclast                 1378
# proliferating EC             26
# schwann cells                 9
# sinusoidal EC               550
# stromal macrophage         1493
# tip EC                      363
# dtype: int64

# %%
# order tissue_cell.labels column

adata.obs["cell.labels"] = adata.obs["cell.labels"].astype("category")

final_order = ['stromal macrophage',
'monocytoid macrophage',
'EI macrophage',
'osteoclast',
'immature EC',
'sinusoidal EC',
'proliferating EC',
'tip EC',
'endosteal fibroblast',
'arteriolar fibroblast',
'myofibroblast',
'muscle',
'schwann cells',
'osteochondral precursor',
'adipo-CAR',
'osteoblast precursor',
'early osteoblast',
'osteoblast',
'chondrocyte']

adata.obs["cell.labels"] = adata.obs["cell.labels"].cat.reorder_categories(final_order)

# %%
cell_numbers = adata.obs.groupby(["cell.labels"]).apply(len)
cell_numbers
# Out:
# cell.labels
# stromal macrophage         1493
# monocytoid macrophage       296
# EI macrophage                92
# osteoclast                 1378
# immature EC                  69
# sinusoidal EC               550
# proliferating EC             26
# tip EC                      363
# endosteal fibroblast         54
# arteriolar fibroblast        84
# myofibroblast                78
# muscle                      474
# schwann cells                 9
# osteochondral precursor     191
# adipo-CAR                   359
# osteoblast precursor        463
# early osteoblast            291
# osteoblast                  375
# chondrocyte                  81
# dtype: int64

# %% [markdown]
# # Pre-process the human stroma dataset

# %%
# normalise count data 
sc.pp.normalize_total(adata)

# %%
# log the count data 
sc.pp.log1p(adata)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 6726 × 33712
#     obs: 'cell.labels', 'doublets', 'fetal.ids', 'gender', 'is_doublet', 'is_doublet_poptrim', 'is_doublet_wolock', 'lanes', 'nGene', 'nUMI', 'orig.ident', 'percent.mito', 'processing.type', 'scrublet_cluster_score', 'scrublet_score', 'sequencing.type', 'sort.ids', 'april_cell.labels', 'cell.labels_broad'
#     var: 'gene_ids-1', 'feature_types-1'
#     obsm: 'X_orig_pca', 'X_pca', 'X_umap'

# %%
# find variable genes
sc.pp.highly_variable_genes(adata, min_mean=0.0125, max_mean=3, min_disp=0.5)

# %%
# scale the data 
sc.pp.scale(adata, max_value=10)

# %%
# scale the negative values in adata.X (which have been normalised, logged and scaled) to zero 
adata.X = np.where(adata.X < 0, 0, adata.X)

# %%
scrna_data = adata

# %% [markdown]
# # Run DEGs for the equivalent Baccin mouse stroma cells and select top 100 genes

# %%
adata = sc.read('/Users/b8058304/Documents/PhD_work/Coding/baccin_mouse/data/mouse_data_raw_20200422.h5ad')

# %%
cell_numbers = adata.obs.groupby(["cell.labels"]).apply(len)
cell_numbers
# Out:
# cell.labels
# Adipo-CAR             528
# Arteriolar ECs         97
# Arteriolar fibro.     376
# B cell                 80
# Chondrocytes           34
# Dendritic cells        61
# Endosteal fibro.      434
# Eo/Baso prog.         337
# Ery prog.             227
# Ery/Mk prog.          598
# Erythroblasts        1197
# Fibro/Chondro p.       69
# Gran/Mono prog.      1157
# LMPPs                1316
# Mk prog.              358
# Mono prog.            520
# Monocytes             210
# Myofibroblasts        439
# NK cells               82
# Neutro prog.          407
# Neutrophils           261
# Ng2+ MSCs             124
# Osteo-CAR              57
# Osteoblasts            53
# Schwann cells          89
# Sinusoidal ECs        109
# Smooth muscle          22
# Stromal fibro.        109
# T cells               136
# large pre-B.          135
# pro-B                 291
# small pre-B.          183
# dtype: int64

# %%
adata = adata[adata.obs['cell.labels'].isin(["Arteriolar ECs", "Sinusoidal ECs", "Schwann cells", "Adipo-CAR", 
                                            "Osteo-CAR", "Osteoblasts", "Chondrocytes", "Fibro/Chondro p.", 
                                             "Arteriolar fibro.", "Endosteal fibro.", "Smooth muscle", 
                                             "Myofibroblasts", "Ng2+ MSCs", "Stromal fibro."])].copy()

# %%
cell_numbers = adata.obs.groupby(["cell.labels"]).apply(len)
cell_numbers
# Out:
# cell.labels
# Adipo-CAR            528
# Arteriolar ECs        97
# Arteriolar fibro.    376
# Chondrocytes          34
# Endosteal fibro.     434
# Fibro/Chondro p.      69
# Myofibroblasts       439
# Ng2+ MSCs            124
# Osteo-CAR             57
# Osteoblasts           53
# Schwann cells         89
# Sinusoidal ECs       109
# Smooth muscle         22
# Stromal fibro.       109
# dtype: int64

# %%
# order tissue_cell.labels column

adata.obs["cell.labels"] = adata.obs["cell.labels"].astype("category")

adata.obs["cell.labels"] = adata.obs["cell.labels"].cat.reorder_categories([
'Sinusoidal ECs',
'Arteriolar ECs', 
'Endosteal fibro.',
'Arteriolar fibro.',
'Myofibroblasts',
'Stromal fibro.',
'Smooth muscle',
'Schwann cells',
'Ng2+ MSCs',
'Adipo-CAR',
'Osteo-CAR',
'Osteoblasts', 
'Fibro/Chondro p.',
'Chondrocytes'])

cell_numbers = adata.obs.groupby(["cell.labels"]).apply(len)
cell_numbers
# Out:
# cell.labels
# Sinusoidal ECs       109
# Arteriolar ECs        97
# Endosteal fibro.     434
# Arteriolar fibro.    376
# Myofibroblasts       439
# Stromal fibro.       109
# Smooth muscle         22
# Schwann cells         89
# Ng2+ MSCs            124
# Adipo-CAR            528
# Osteo-CAR             57
# Osteoblasts           53
# Fibro/Chondro p.      69
# Chondrocytes          34
# dtype: int64

# %%
# normalise count data 
sc.pp.normalize_total(adata)

# %%
# log the count data 
sc.pp.log1p(adata)

# %%
# find variable genes
sc.pp.highly_variable_genes(adata, min_mean=0.0125, max_mean=3, min_disp=0.5)

# %%
# scale the data 
sc.pp.scale(adata, max_value=10)

# %%
# scale the negative values in adata.X (which have been normalised, logged and scaled) to zero 
adata.X = np.where(adata.X < 0, 0, adata.X)

# %%
# run degs on normalised and logged data (saved as adata.raw), not on additionally scaled data (saved as adata.X).
# calculate degs using wilcoxon rank sum test with benjamini-hochberg correction. 
#based on ln transformed count data 
sc.tl.rank_genes_groups(adata, groupby='cell.labels', method='wilcoxon', use_raw=False, log_transformed=True, n_genes=1000)

# %%
# filter the degs for those which are expressed in at least 25% of cells in cluster. log2fc of the ln-transformed
# data will be shown.
sc.tl.filter_rank_genes_groups(adata, min_in_group_fraction=0.25, min_fold_change=0.25, use_raw=False)

# %%
# save df for unfiltered degs
result = adata.uns['rank_genes_groups']
groups = result['names'].dtype.names
degs_by_cluster = pd.DataFrame({group + '_' + key[:1]: result[key][group]
    for group in groups for key in ['names', 'logfoldchanges']})

# the degs_by_cluster df shows the log2 fold change for each gene ordered by z-score underlying the computation 
# of a p-value for each gene for each group
degs_by_cluster.to_csv("/Users/b8058304/Documents/PhD_work/Coding/manuscript_figs/figs/clustering_degs/mouse_stroma_degs.csv")
degs_by_cluster[:10]
# Out:
#   Sinusoidal ECs_n  Sinusoidal ECs_l Arteriolar ECs_n  Arteriolar ECs_l  \
# 0            Plvap          9.777742           Tm4sf1          5.844638
# 1            Sepp1          3.778103             Ly6e          5.235610
# 2            Gng11          4.239138         Slc9a3r2          7.828618
# 3            Cldn5          6.803056            Ly6c1          3.499561
# 4            Egfl7          6.886823            Egfl7          6.804814
# 5             Lrg1          8.804356             Esam          7.211186
# 6             Tcn2          5.311046             Cav1          5.705824
# 7             Ly6e          3.532060            Sox17         10.411519
# 8             Cdh5          7.372761            Fabp4          6.668997
# 9             Esam          6.243892           Pecam1          5.178740
#
#   Endosteal fibro._n  Endosteal fibro._l Arteriolar fibro._n  \
# 0               Pi16            4.876131            Serpinf1
# 1              Mfap5            4.092308                 Dcn
# 2             S100a6            2.825019              Col3a1
# 3               Ly6a            3.515509              Pcolce
# 4             Clec3b            3.806894                Nbl1
# 5               Cd34            3.339982                 Gsn
# 6              Ly6c1            3.344826                Gas1
# 7              Fstl1            2.859972              Col1a1
# 8             Igfbp6            3.289869              Col1a2
# 9              Timp2            2.904427              Igfbp6
#
#    Arteriolar fibro._l Myofibroblasts_n  Myofibroblasts_l  ... Adipo-CAR_n  \
# 0             3.232969           Rpl18a          3.859416  ...      Cxcl12
# 1             2.611412             Rps5          3.893073  ...          Hp
# 2             3.138335             Rps6          3.855688  ...    Tmem176b
# 3             2.519043            Rps19          3.904289  ...         Lpl
# 4             2.721031            Rpl13          3.653038  ...    Tmem176a
# 5             2.448025            Rps14          3.534955  ...      Adipoq
# 6             2.992189            Rps4x          3.491280  ...       H2-D1
# 7             2.233126            Rps18          3.540536  ...        Apoe
# 8             1.836366            Rpl37          3.554471  ...        Esm1
# 9             2.445596            Rplp0          3.491497  ...        Gas6
#
#    Adipo-CAR_l Osteo-CAR_n  Osteo-CAR_l Osteoblasts_n  Osteoblasts_l  \
# 0     6.117310         Tnc     5.628873        Col1a1       5.439332
# 1     7.998065        Wif1     6.851064        Col1a2       5.172942
# 2     4.902675       Kcnk2     8.486124        Ifitm5      11.087225
# 3     6.970576        Alpl     5.983037         Sparc       3.671983
# 4     4.494699      Igfbp4     2.889747      Serpinh1       2.993809
# 5     7.931683      Olfml3     3.769314         Cadm1       7.727442
# 6     3.830194         B2m     2.632725        Cgref1       9.770432
# 7     3.918617        Rgs3     4.388453          Car3      10.070471
# 8     6.159978        Cd63     2.509048        Fkbp11       7.367804
# 9     4.083918      Limch1     6.777151           Cpe       5.243202
#
#   Fibro/Chondro p._n  Fibro/Chondro p._l Chondrocytes_n  Chondrocytes_l
# 0               Comp            5.210753         Col9a3       13.792507
# 1             Lgals3            4.147619         Col9a2       13.917876
# 2              Mfge8            3.898006          Lect1       14.413549
# 3            Tsc22d1            3.024973         Col9a1       14.772593
# 4               Fmod            7.193307         Hapln1       12.695127
# 5              Fxyd5            3.245221        Col11a1        9.666176
# 6               Chad            7.502733            Mia       13.899599
# 7                Cd9            2.385819  3110079O15Rik       13.993590
# 8               Rgcc            3.033925         Col2a1       15.796575
# 9              Sparc            2.207354          Sparc        3.409082
#
# [10 rows x 28 columns]

# %%
# save df for filtered degs
result = adata.uns['rank_genes_groups_filtered']
groups = result['names'].dtype.names
degs_by_cluster_filtered = pd.DataFrame({group + '_' + key[:1]: result[key][group]
    for group in groups for key in ['names', 'logfoldchanges']})
# the degs_by_cluster df shows the log2 fold change for each gene ordered by z-score underlying the computation 
# of a p-value for each gene for each group
degs_by_cluster_filtered.to_csv("/Users/b8058304/Documents/PhD_work/Coding/manuscript_figs/figs/clustering_degs/mouse_stroma_degs_filtered.csv")
degs_by_cluster_filtered[:10]
# Out:
#   Sinusoidal ECs_n  Sinusoidal ECs_l Arteriolar ECs_n  Arteriolar ECs_l  \
# 0            Plvap          9.777742           Tm4sf1          5.844638
# 1            Sepp1          3.778103             Ly6e          5.235610
# 2            Gng11          4.239138         Slc9a3r2          7.828618
# 3            Cldn5          6.803056            Ly6c1          3.499561
# 4            Egfl7          6.886823            Egfl7          6.804814
# 5             Lrg1          8.804356             Esam          7.211186
# 6             Tcn2          5.311046             Cav1          5.705824
# 7             Ly6e          3.532060            Sox17         10.411519
# 8             Cdh5          7.372761            Fabp4          6.668997
# 9             Esam          6.243892           Pecam1          5.178740
#
#   Endosteal fibro._n  Endosteal fibro._l Arteriolar fibro._n  \
# 0               Pi16            4.876131            Serpinf1
# 1              Mfap5            4.092308                 Dcn
# 2             S100a6            2.825019              Col3a1
# 3               Ly6a            3.515509              Pcolce
# 4             Clec3b            3.806894                Nbl1
# 5               Cd34            3.339982                 Gsn
# 6              Ly6c1            3.344826                Gas1
# 7              Fstl1            2.859972              Col1a1
# 8             Igfbp6            3.289869              Col1a2
# 9              Timp2            2.904427              Igfbp6
#
#    Arteriolar fibro._l Myofibroblasts_n  Myofibroblasts_l  ... Adipo-CAR_n  \
# 0             3.232969           Rpl18a          3.859416  ...      Cxcl12
# 1             2.611412             Rps5          3.893073  ...          Hp
# 2             3.138335             Rps6          3.855688  ...    Tmem176b
# 3             2.519043            Rps19          3.904289  ...         Lpl
# 4             2.721031            Rpl13          3.653038  ...    Tmem176a
# 5             2.448025            Rps14          3.534955  ...      Adipoq
# 6             2.992189            Rps4x          3.491280  ...       H2-D1
# 7             2.233126            Rps18          3.540536  ...        Apoe
# 8             1.836366            Rpl37          3.554471  ...        Esm1
# 9             2.445596            Rplp0          3.491497  ...        Gas6
#
#    Adipo-CAR_l Osteo-CAR_n  Osteo-CAR_l Osteoblasts_n  Osteoblasts_l  \
# 0     6.117310         Tnc     5.628873        Col1a1       5.439332
# 1     7.998065        Wif1     6.851064           NaN       5.172942
# 2     4.902675       Kcnk2     8.486124        Ifitm5      11.087225
# 3     6.970576        Alpl     5.983037           NaN       3.671983
# 4     4.494699      Igfbp4     2.889747           NaN       2.993809
# 5     7.931683      Olfml3     3.769314         Cadm1       7.727442
# 6     3.830194         B2m     2.632725        Cgref1       9.770432
# 7     3.918617        Rgs3     4.388453          Car3      10.070471
# 8     6.159978         NaN     2.509048        Fkbp11       7.367804
# 9     4.083918      Limch1     6.777151           Cpe       5.243202
#
#   Fibro/Chondro p._n  Fibro/Chondro p._l Chondrocytes_n  Chondrocytes_l
# 0               Comp            5.210753         Col9a3       13.792507
# 1             Lgals3            4.147619         Col9a2       13.917876
# 2              Mfge8            3.898006          Lect1       14.413549
# 3            Tsc22d1            3.024973         Col9a1       14.772593
# 4               Fmod            7.193307         Hapln1       12.695127
# 5              Fxyd5            3.245221        Col11a1        9.666176
# 6               Chad            7.502733            Mia       13.899599
# 7                NaN            2.385819  3110079O15Rik       13.993590
# 8               Rgcc            3.033925         Col2a1       15.796575
# 9                NaN            2.207354            NaN        3.409082
#
# [10 rows x 28 columns]

# %%
cell_numbers = adata.obs.groupby(["cell.labels"]).apply(len)
cell_numbers
# Out:
# cell.labels
# Sinusoidal ECs       109
# Arteriolar ECs        97
# Endosteal fibro.     434
# Arteriolar fibro.    376
# Myofibroblasts       439
# Stromal fibro.       109
# Smooth muscle         22
# Schwann cells         89
# Ng2+ MSCs            124
# Adipo-CAR            528
# Osteo-CAR             57
# Osteoblasts           53
# Fibro/Chondro p.      69
# Chondrocytes          34
# dtype: int64

# %% [markdown]
# # Convert DEG list to human genes in R/py

# %%
# convert anndata to sce
import anndata2ri
anndata2ri.activate()
# %load_ext rpy2.ipython
# Out:
# /Users/b8058304/.pyenv/versions/3.6.4/envs/py36/lib/python3.6/site-packages/rpy2/robjects/pandas2ri.py:34: UserWarning: pandas >= 1.0 is not supported.
#   warnings.warn('pandas >= 1.0 is not supported.')

# %%
# %R d = as.data.frame( R.Version() )
# %R d = d['version.string']
# Out:
#                  version.string
# 1  R version 3.6.2 (2019-12-12)

# %%
# %%R
#
# library(scran)
# library(RColorBrewer)
# library(slingshot)
# library(monocle)
# library(gam)
# library(clusterExperiment)
# library(ggplot2)
# library(plyr)
# Out:
# R[write to console]: Loading required package: SingleCellExperiment
#
# R[write to console]: Loading required package: SummarizedExperiment
#
# R[write to console]: Loading required package: GenomicRanges
#
# R[write to console]: Loading required package: stats4
#
# R[write to console]: Loading required package: BiocGenerics
#
# R[write to console]: Loading required package: parallel
#
# R[write to console]:
# Attaching package: ‘BiocGenerics’
#
#
# R[write to console]: The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
#
# R[write to console]: The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# R[write to console]: The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colnames,
#     dirname, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, setdiff, sort, table, tapply,
#     union, unique, unsplit, which, which.max, which.min
#
#
# R[write to console]: Loading required package: S4Vectors
#
# R[write to console]:
# Attaching package: ‘S4Vectors’
#
#
# R[write to console]: The following object is masked from ‘package:base’:
#
#     expand.grid
#
#
# R[write to console]: Loading required package: IRanges
#
# R[write to console]: Loading required package: GenomeInfoDb
#
# R[write to console]: Loading required package: Biobase
#
# R[write to console]: Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# R[write to console]: Loading required package: DelayedArray
#
# R[write to console]: Loading required package: matrixStats
#
# R[write to console]:
# Attaching package: ‘matrixStats’
#
#
# R[write to console]: The following objects are masked from ‘package:Biobase’:
#
#     anyMissing, rowMedians
#
#
# R[write to console]: Loading required package: BiocParallel
#
# R[write to console]:
# Attaching package: ‘DelayedArray’
#
#
# R[write to console]: The following objects are masked from ‘package:matrixStats’:
#
#     colMaxs, colMins, colRanges, rowMaxs, rowMins, rowRanges
#
#
# R[write to console]: The following objects are masked from ‘package:base’:
#
#     aperm, apply, rowsum
#
#
# R[write to console]: Loading required package: princurve
#
# R[write to console]: Loading required package: Matrix
#
# R[write to console]:
# Attaching package: ‘Matrix’
#
#
# R[write to console]: The following object is masked from ‘package:S4Vectors’:
#
#     expand
#
#
# R[write to console]: Loading required package: ggplot2
#
# R[write to console]: Loading required package: VGAM
#
# R[write to console]: Loading required package: splines
#
# R[write to console]: Loading required package: DDRTree
#
# R[write to console]: Loading required package: irlba
#
# R[write to console]: Loading required package: foreach
#
# R[write to console]: Loaded gam 1.16.1
#
#
# R[write to console]:
# Attaching package: ‘gam’
#
#
# R[write to console]: The following object is masked from ‘package:VGAM’:
#
#     s
#
#
# R[write to console]: Warning:
# R[write to console]:  namespace ‘bigmemory’ is not available and has been replaced
# by .GlobalEnv when processing object ‘’
#
# R[write to console]: Warning:
# R[write to console]:  namespace ‘bigmemory’ is not available and has been replaced
# by .GlobalEnv when processing object ‘’
#
# R[write to console]:
# Attaching package: ‘plyr’
#
#
# R[write to console]: The following object is masked from ‘package:matrixStats’:
#
#     count
#
#
# R[write to console]: The following object is masked from ‘package:IRanges’:
#
#     desc
#
#
# R[write to console]: The following object is masked from ‘package:S4Vectors’:
#
#     rename

# %%
# %%R
#
# # create a key to map the mouse DEGs to human DEGs (in R, usng biomart)
#
# # Load the filtered DEGs in
# mouse_degs_filtered <- read.csv("/Users/b8058304/Documents/PhD_work/Coding/manuscript_figs/figs/clustering_degs/mouse_stroma_degs_filtered.csv")
# mouse_degs_filtered
#
# # load the biomart needed for conversion
# require("biomaRt")
# human = useMart("ensembl", dataset = "hsapiens_gene_ensembl")
# mouse = useMart("ensembl", dataset = "mmusculus_gene_ensembl")
#
# # make df = all columns ending with _n (i.e., cols with mouse gene names in)
# df = mouse_degs_filtered[, -grep("_l", colnames(mouse_degs_filtered))]
# # remove index column
# df <- subset(df, select = -c(X))
# df
# colnames(df)
#
# # run a loop to save a df of the MGI.symbol (mouse genes) and corresponding (human genes) for each celltype DEG col
# final_gene_key = list()
# for (i in colnames(df)){
#   # print the celltype column we are looking at degs for
#   print(i)
#   # save gene key for conversion of these genes as a df
#   column_gene_key = getLDS(attributes = c("mgi_symbol"), filters = "external_gene_name", values = df[[i]],
#                            mart = mouse, attributesL = c("external_gene_name"), martL = human, uniqueRows=T)
#   print(head(column_gene_key))
#   print('printing size of this celltypes DEGs')
#   print(nrow(column_gene_key))
#   print('printing size of combined celltype DEGs')
#   final_gene_key = rbind(column_gene_key, final_gene_key)
#   print(nrow(final_gene_key))
# }
#
# # save the conversion mouse to human key for input into python
# write.csv(final_gene_key, "/Users/b8058304/Documents/PhD_work/Coding/manuscript_figs/figs/clustering_degs/mouse_stroma_degs_filtered_species_gene_key.csv")
# Out:
# R[write to console]: Loading required package: biomaRt
#
# R[write to console]: Error in bmRequest(request = request, verbose = verbose) :
#   Internal Server Error (HTTP 500).
# Calls: <Anonymous> ... useDataset -> bmAttrFilt -> bmRequest -> stop_for_status
# Error in bmRequest(request = request, verbose = verbose) :
#   Internal Server Error (HTTP 500).
# Calls: <Anonymous> ... useDataset -> bmAttrFilt -> bmRequest -> stop_for_status

# %% [markdown]
# # Save top 100 filtered DEGs within dictionary

# %%
# sort the degs_by_cluster_filtered df genes by logfc
degs_by_cluster_filtered = pd.read_csv("/Users/b8058304/Documents/PhD_work/Coding/manuscript_figs/figs/clustering_degs/mouse_stroma_degs_filtered.csv")
df = degs_by_cluster_filtered
df[:5]
# Out:
#    Unnamed: 0 Sinusoidal ECs_n  Sinusoidal ECs_l Arteriolar ECs_n  \
# 0           0            Plvap          9.777742           Tm4sf1
# 1           1            Sepp1          3.778103             Ly6e
# 2           2            Gng11          4.239138         Slc9a3r2
# 3           3            Cldn5          6.803056            Ly6c1
# 4           4            Egfl7          6.886823            Egfl7
#
#    Arteriolar ECs_l Endosteal fibro._n  Endosteal fibro._l  \
# 0          5.844638               Pi16            4.876131
# 1          5.235610              Mfap5            4.092308
# 2          7.828618             S100a6            2.825019
# 3          3.499561               Ly6a            3.515509
# 4          6.804814             Clec3b            3.806894
#
#   Arteriolar fibro._n  Arteriolar fibro._l Myofibroblasts_n  ...  Adipo-CAR_n  \
# 0            Serpinf1             3.232969           Rpl18a  ...       Cxcl12
# 1                 Dcn             2.611412             Rps5  ...           Hp
# 2              Col3a1             3.138335             Rps6  ...     Tmem176b
# 3              Pcolce             2.519043            Rps19  ...          Lpl
# 4                Nbl1             2.721031            Rpl13  ...     Tmem176a
#
#   Adipo-CAR_l  Osteo-CAR_n Osteo-CAR_l  Osteoblasts_n Osteoblasts_l  \
# 0    6.117310          Tnc    5.628873         Col1a1      5.439332
# 1    7.998066         Wif1    6.851064            NaN      5.172942
# 2    4.902675        Kcnk2    8.486124         Ifitm5     11.087225
# 3    6.970576         Alpl    5.983038            NaN      3.671983
# 4    4.494699       Igfbp4    2.889747            NaN      2.993809
#
#    Fibro/Chondro p._n Fibro/Chondro p._l  Chondrocytes_n Chondrocytes_l
# 0                Comp           5.210753          Col9a3      13.792507
# 1              Lgals3           4.147619          Col9a2      13.917876
# 2               Mfge8           3.898006           Lect1      14.413549
# 3             Tsc22d1           3.024973          Col9a1      14.772593
# 4                Fmod           7.193307          Hapln1      12.695127
#
# [5 rows x 29 columns]

# %%
# use the species conversion key to replace genes in DEGs csv and filter for top 100 by logfc
# 1 - for each celltype, sort DEGs by logfc
# 2 - convert mouse genes to human genes (else, turn to nan)
# 3 - remove nans
# select top 100

gene_key = pd.read_csv("/Users/b8058304/Documents/PhD_work/Coding/manuscript_figs/figs/clustering_degs/mouse_stroma_degs_filtered_species_gene_key.csv")
mouse_gene_list = gene_key["MGI.symbol"].tolist()
human_gene_list = gene_key["Gene.name"].tolist()
my_dict = {}

for i in adata.obs["cell.labels"].cat.categories:
    # for each DEG list:
    print(i)
    # assign cols
    gene_name = str(i) + "_n"
    logfc = str(i) + "_l"
    
    # sort values of genes based on logfc
    df = df.sort_values([logfc], ascending=False)
    gene_list = df[gene_name]
    # convert mouse genes to human genes
    gene_list = gene_list.replace(mouse_gene_list, human_gene_list)
    # if any mouse genes left over, convert to NAN
    gene_list = gene_list.replace(mouse_gene_list, 'nan')
    # remove nan values from genes
    cleanedList = [x for x in gene_list if str(x) != 'nan']
    #get top 100 genes
    top_100_genes = cleanedList[:100] 
    # save 100 degs as values in key named "celltype"_degs
    x = str(i) + "_degs"
    my_dict[x] = top_100_genes
    
# save df of top 100 humanised DEGs for mouse celltypes
final_mouse_degs = pd.DataFrame.from_dict(my_dict)
final_mouse_degs.to_csv("/Users/b8058304/Documents/PhD_work/Coding/manuscript_figs/figs/clustering_degs/mouse_humanised_top_100_degs.csv")
final_mouse_degs[:5]
# Out:
# Sinusoidal ECs
# Arteriolar ECs
# Endosteal fibro.
# Arteriolar fibro.
# Myofibroblasts
# Stromal fibro.
# Smooth muscle
# Schwann cells
# Ng2+ MSCs
# Adipo-CAR
# Osteo-CAR
# Osteoblasts
# Fibro/Chondro p.
# Chondrocytes
#   Sinusoidal ECs_degs Arteriolar ECs_degs Endosteal fibro._degs  \
# 0              GPR182               PTPRR                 LYPD2
# 1             FAM167B               SOX17                  WNT2
# 2            DNASE1L3              SEMA3G                SEMA3C
# 3               STAB2             C1QTNF9                 CD248
# 4                MRC1                GJA4                 ISLR2
#
#   Arteriolar fibro._degs Myofibroblasts_degs Stromal fibro._degs  \
# 0                  MFAP4               FGFR4             ANGPTL7
# 1                  FBLN7              CHRNA1               CCL11
# 2                  CPXM2              CHRDL2            CRISPLD2
# 3                   CILP                PAX7             COL15A1
# 4                 ITGBL1               CHODL                APOD
#
#   Smooth muscle_degs Schwann cells_degs Ng2+ MSCs_degs Adipo-CAR_degs  \
# 0             OR51E1             MAP6D1           SPP1             HP
# 1           Map3k7cl               ST18           DMP1         ADIPOQ
# 2              MYH11            DSCAML1          MMP13          IL1RN
# 3              CASQ2              OLIG2            VDR            LPL
# 4                PLN              Haglr          SLIT2           KNG1
#
#   Osteo-CAR_degs Osteoblasts_degs Fibro/Chondro p._degs Chondrocytes_degs
# 0         ANGPT4           IFITM5                 CILP2          SERPINA1
# 1          KCNK2            BGLAP                  CHAD            COL2A1
# 2           WIF1            BGLAP                  FMOD             MATN3
# 3         LIMCH1              CPZ              NDUFA4L2            COL9A1
# 4        SLC36A2            BGLAP                  Mfi2             Lect1

# %%
my_dict
# Out:
# {'Sinusoidal ECs_degs': ['GPR182',
#   'FAM167B',
#   'DNASE1L3',
#   'STAB2',
#   'MRC1',
#   'PLVAP',
#   'SELP',
#   'STAB1',
#   'CYP4B1',
#   'Ctla2a',
#   'APLNR',
#   'LIPG',
#   'UBD',
#   'GPIHBP1',
#   'KDR',
#   'LRG1',
#   'GPM6A',
#   'BTNL9',
#   'LTC4S',
#   'FLT4',
#   'CD300LG',
#   'Clca3a1',
#   'IPO11',
#   'ROBO4',
#   'EMCN',
#   'KCNJ8',
#   'USHBP1',
#   'CDH5',
#   'CMTM8',
#   'GIMAP6',
#   'GIMAP4',
#   'EGFL7',
#   'CLDN5',
#   'TP53I11',
#   'MMRN2',
#   'RASIP1',
#   'KANK3',
#   'FABP4',
#   'TIE1',
#   'ADGRL4',
#   'CD38',
#   'FLT1',
#   'APOLD1',
#   'ESAM',
#   'ACKR1',
#   'SOX18',
#   'ABCC9',
#   'CD93',
#   'UPP1',
#   'ECSCR',
#   'TRIM37',
#   'F11R',
#   'MYCT1',
#   'TFPI',
#   'Pvrl2',
#   'PDE2A',
#   'TCN2',
#   'CRACR2B',
#   'PTPRB',
#   'LDB2',
#   'FCER1G',
#   'TMEM88',
#   'TMEM204',
#   'MCAM',
#   'SMAGP',
#   'ICAM2',
#   'CYYR1',
#   'C4orf48',
#   'ENG',
#   'ADGRG1',
#   'ETS1',
#   'STOM',
#   'SCARB1',
#   'SLCO2A1',
#   'CLEC14A',
#   'GALNT18',
#   'CD36',
#   'GNG11',
#   'BOK',
#   'TEK',
#   'PLPP1',
#   'GNGT2',
#   'ELK3',
#   'AC004691.2',
#   'SH3BP5',
#   'NRARP',
#   'TM6SF1',
#   'SRGN',
#   'NR2F2',
#   'PRCP',
#   'LGMN',
#   'Sepp1',
#   'Bvht',
#   'PREX2',
#   'ETS2',
#   'Abcg2',
#   'ENPP6',
#   'EFNA1',
#   'COTL1',
#   'LY6E'],
#  'Arteriolar ECs_degs': ['PTPRR',
#   'SOX17',
#   'SEMA3G',
#   'C1QTNF9',
#   'GJA4',
#   'EDN1',
#   'STMN2',
#   'PODXL',
#   'Ceacam1',
#   'GATA2',
#   'SLC9A3R2',
#   'CD36',
#   'TINAGL1',
#   'PTPRB',
#   'ICAM2',
#   'BCAM',
#   'ESAM',
#   'TM6SF1',
#   'MALL',
#   'EPS8L2',
#   'EGFL7',
#   'TSPAN13',
#   'FAM181B',
#   'MYCT1',
#   'TCF15',
#   'FABP4',
#   'MECOM',
#   'FLT1',
#   'MMRN2',
#   'CLDN5',
#   'CAV2',
#   'F11R',
#   'ADGRG1',
#   'SOX18',
#   'PCDH1',
#   'CDH5',
#   '8430408G22Rik',
#   'ADCY4',
#   'ENG',
#   'TM4SF1',
#   'CD93',
#   'CRACR2B',
#   'ADGRL4',
#   'CYYR1',
#   'CAV1',
#   'TIE1',
#   'ADAM15',
#   'PREX2',
#   'JAM2',
#   'CLEC14A',
#   'TMEM88',
#   'RASIP1',
#   'Nebl',
#   'HSPA12B',
#   'LY6E',
#   'ECSCR',
#   'PECAM1',
#   'SNCG',
#   'TSPAN7',
#   'LRRC32',
#   'CDK19',
#   'RASSF3',
#   'GIMAP4',
#   'PDGFD',
#   'APOLD1',
#   'UACA',
#   'EMCN',
#   'LIMS2',
#   'TRPV4',
#   'FLI1',
#   'AC015802.6',
#   'KCTD10',
#   'NRARP',
#   'SRGN',
#   'PLS3',
#   'KANK3',
#   'Fam101b',
#   'Sdpr',
#   'LMCD1',
#   'CD59',
#   'GIMAP6',
#   'EFNA1',
#   'PALMD',
#   'JAG1',
#   'SLC6A6',
#   'TEK',
#   'DUSP26',
#   'ID1',
#   'IGF2',
#   'ADGRF5',
#   'TMOD3',
#   'S1PR1',
#   'EHD4',
#   'ACVRL1',
#   'IRF7',
#   'MGLL',
#   'PLSCR1',
#   'SPARCL1',
#   'B4GALT4',
#   'HEY1'],
#  'Endosteal fibro._degs': ['LYPD2',
#   'WNT2',
#   'SEMA3C',
#   'CD248',
#   'ISLR2',
#   'DPP4',
#   'KRTDAP',
#   'EMILIN2',
#   'ADGRD1',
#   'PI16',
#   'CD55',
#   'PROCR',
#   'LURAP1L',
#   'CADM3',
#   'ZNF385A',
#   'EFHD1',
#   'MFAP5',
#   'Ifi27l2a',
#   'SCARA5',
#   'FBN1',
#   'AXL',
#   'THY1',
#   'LRRN4CL',
#   'FNDC1',
#   'MYOC',
#   'CLEC3B',
#   'PCOLCE2',
#   'ANXA3',
#   'PCSK6',
#   'TGFBR2',
#   'UGDH',
#   'Ly6a',
#   'DBN1',
#   'TNXB',
#   'UCHL1',
#   'MUSTN1',
#   'HAS1',
#   'ACKR3',
#   'ANXA8',
#   'COL14A1',
#   'Ly6c1',
#   'CD34',
#   'Ccdc109b',
#   'PTGS1',
#   'IGFBP6',
#   'AHNAK2',
#   'IL18',
#   'ADAMTSL5',
#   'PAMR1',
#   'EBF2',
#   'P4HA3',
#   'TMEM100',
#   'SULF2',
#   'UAP1',
#   'GFPT2',
#   'FLRT2',
#   'Nov',
#   'UGP2',
#   'ASPN',
#   'EFEMP1',
#   'DNM1',
#   'SERPINB6',
#   'OSR2',
#   'TIMP2',
#   'GNPNAT1',
#   'FSTL1',
#   'METRNL',
#   'VCAN',
#   'TMEM158',
#   'QPCT',
#   'GAS7',
#   'S100A6',
#   'ECM1',
#   'ABLIM1',
#   'THBD',
#   'HSPB8',
#   'MEDAG',
#   'GSN',
#   'AHNAK',
#   'CRIP1',
#   'EMP3',
#   'FYN',
#   'SBSN',
#   'ANXA1',
#   'VAT1',
#   'FBLN2',
#   'HEG1',
#   'OSR1',
#   'HTRA3',
#   'NTN1',
#   'ANPEP',
#   'Prkcdbp',
#   'C1QTNF7',
#   'RHOQ',
#   'CREB5',
#   'ADAMTSL3',
#   'ANXA2',
#   'OLFML2A',
#   'PPP1R14B',
#   'S100A10'],
#  'Arteriolar fibro._degs': ['MFAP4',
#   'FBLN7',
#   'CPXM2',
#   'CILP',
#   'ITGBL1',
#   'ANGPTL1',
#   'BOC',
#   'C1QTNF2',
#   'SMOC2',
#   'PRRX2',
#   'SERPINF1',
#   'ELN',
#   'COL3A1',
#   'TMEM119',
#   'ANPEP',
#   'GAS1',
#   'TGFBI',
#   'CYGB',
#   'ECM2',
#   'AL162231.3',
#   'MN1',
#   'ASPN',
#   'NBL1',
#   'THBS2',
#   'CCDC80',
#   'COL6A3',
#   'RBP1',
#   'PODN',
#   'AEBP1',
#   'FGL2',
#   'DCN',
#   'FHL1',
#   'PCOLCE',
#   'PDGFRL',
#   'MMP2',
#   'MGP',
#   'FBLN1',
#   'DPT',
#   'GSN',
#   'IGFBP6',
#   'COL15A1',
#   'IGF1',
#   'DKK3',
#   'CLEC3B',
#   'COL14A1',
#   'NDUFA4L2',
#   'OGN',
#   'LUM',
#   'MEOX2',
#   'ENTPD2',
#   'STEAP3',
#   'SVIL',
#   'COL1A1',
#   'THBS3',
#   'SLC66A3',
#   'PTHLH',
#   'SPARCL1',
#   'COL5A2',
#   'MATN2',
#   'ATF5',
#   'COMP',
#   'MFAP5',
#   'ITM2A',
#   'CTSK',
#   'APOD',
#   'CLEC11A',
#   'ZIC1',
#   'LSP1',
#   'Mxra7',
#   'HEXB',
#   'COL1A2',
#   'CHPF',
#   'COL6A2',
#   'FN1',
#   'MFAP2',
#   'NAAA',
#   'ANK2',
#   'RNASE4',
#   'NUCB2',
#   'PAMR1',
#   'LOXL2',
#   'CAPG',
#   'PRNP',
#   'TIMP2',
#   'LRP1',
#   'IGFBP7',
#   'TMEM100',
#   'CSRP2',
#   'LAMB2',
#   'TNXB',
#   'TGFB3',
#   'Nov',
#   'SOD3',
#   'PRRX1',
#   'SIGMAR1',
#   'ISLR',
#   'FBLN2',
#   'Abca8a',
#   'CST3',
#   'COL12A1'],
#  'Myofibroblasts_degs': ['FGFR4',
#   'CHRNA1',
#   'CHRDL2',
#   'PAX7',
#   'CHODL',
#   'ANKRD1',
#   'ANK1',
#   'ASB5',
#   'MYF5',
#   'MYOD1',
#   'VGLL2',
#   'CHRNB1',
#   'DES',
#   'DEFB124',
#   'CDH15',
#   'CRLF1',
#   'CD82',
#   'ARL4D',
#   'F2R',
#   'HSD11B1',
#   'PDE4B',
#   'TNFRSF12A',
#   'PEG3',
#   'FOSL1',
#   'RPS19',
#   'RPS5',
#   'RPL18A',
#   'RPS6',
#   'FXYD6',
#   'C1QTNF3',
#   'ACTA2',
#   'RPL13',
#   'Meg3',
#   'Rpl17',
#   'RPL37',
#   'RPS18',
#   'RPS14',
#   'RPL3',
#   'Rplp0',
#   'RPS4X',
#   'MSC',
#   'RPL4',
#   'IFRD1',
#   'DAG1',
#   'EEF2',
#   'RPS3',
#   'MAFF',
#   'Gm16833',
#   'SERPINE1',
#   'Rps7',
#   'RPS23',
#   'RPL26',
#   'PDLIM4',
#   'Rpl14',
#   'RPS8',
#   'Gm8730',
#   'RPL18',
#   'SPATS2L',
#   'RPS3A',
#   'SRXN1',
#   'RPS9',
#   'RPL32',
#   'TGIF1',
#   'RPL35A',
#   'RPL8',
#   'RPS28',
#   'HEYL',
#   'NCAM1',
#   'Rpl36a',
#   'RPL36',
#   'RPS16',
#   'MYL12A',
#   'Eef1a1',
#   'RPS27A',
#   'Rpl24',
#   'Rpl6l',
#   'RPL23',
#   'Gm15013',
#   'RPL11',
#   'P2RY14',
#   'RPL39',
#   'RPL6',
#   'Rpl7',
#   'FAS',
#   'ERRFI1',
#   'RPL10A',
#   'PXDC1',
#   'RPS2',
#   'Rpl21',
#   'RPL9',
#   'RPS15A',
#   'RPL13A',
#   'Gm9493',
#   'RPL34',
#   'BAG3',
#   'RPS15',
#   'CUX1',
#   'RPL19',
#   'HSPB1',
#   'UBC'],
#  'Stromal fibro._degs': ['ANGPTL7',
#   'CCL11',
#   'CRISPLD2',
#   'COL15A1',
#   'APOD',
#   'SMOC2',
#   'GPC3',
#   'ATP1A2',
#   'SPARCL1',
#   'VTN',
#   'RDH10',
#   'ENPP2',
#   'LUM',
#   'OSR2',
#   'MATN2',
#   'EFEMP1',
#   'RAMP1',
#   'NTRK2',
#   'NR2F2',
#   'IL33',
#   'LAMA2',
#   'PODN',
#   'CPE',
#   'Cxcl1',
#   'VWA1',
#   'PHLDA1',
#   'DCN',
#   'THBS1',
#   'Abca8a',
#   'MMP2',
#   'ENTPD2',
#   'GSN',
#   'TNFAIP6',
#   'TNFSF9',
#   'GAS7',
#   'QPCT',
#   'TGFBI',
#   'RGMB',
#   'KCNK2',
#   'STEAP3',
#   'AKAP12',
#   'VIT',
#   'PDGFRL',
#   'PLAT',
#   'GM2A',
#   'GFPT2',
#   'GLIPR2',
#   'BHLHE40',
#   'C1S',
#   'Nov',
#   'SPRY2',
#   'CP',
#   'NDN',
#   'KDM6B',
#   'GEM',
#   'RAB34',
#   'PSIP1',
#   'HK2',
#   'SRPX',
#   'CCL2',
#   'CCL7',
#   'TCF4',
#   'THY1',
#   'HSPG2',
#   'CD34',
#   'ZBTB20',
#   'OAF',
#   'PPP1R15A',
#   'PRKCA',
#   'NR4A1',
#   'PLTP',
#   'PNP',
#   'SAT1',
#   'MYOC',
#   'ISLR',
#   'NOP58',
#   'SDC2',
#   'NID1',
#   'RBP1',
#   'IRF1',
#   'SULF1',
#   'ITM2A',
#   'Dnaja1',
#   'TIPARP',
#   'ADD3',
#   'SLC39A1',
#   'CYGB',
#   'PRRC2C',
#   'KLF9',
#   'LAMC1',
#   'CPXM1',
#   'NDRG2',
#   'PAM',
#   'SCPEP1',
#   'IGFBP6',
#   'PDGFRA',
#   'ECM1',
#   'MYD88',
#   'PPP1R2',
#   'TUBB6'],
#  'Smooth muscle_degs': ['OR51E1',
#   'Map3k7cl',
#   'MYH11',
#   'CASQ2',
#   'PLN',
#   'TAGLN',
#   'MYL9',
#   'TPM2',
#   'TESC',
#   'KCNA5',
#   'PCP4L1',
#   'ACTA2',
#   'RGS5',
#   'FBXL22',
#   'SNCG',
#   'EPHX3',
#   'LMOD1',
#   'Gucy1a3',
#   'NRIP2',
#   'CABP1',
#   'ASB2',
#   'RBPMS2',
#   'Gm13861',
#   'ATP1B2',
#   'MRVI1',
#   'JPH2',
#   'RGS7BP',
#   'SBSPON',
#   'NRARP',
#   'RASL12',
#   'Gucy1b3',
#   'PDE3A',
#   'C11orf96',
#   'CCDC85A',
#   'MUSTN1',
#   'FAM81A',
#   'RBM24',
#   'ANO1',
#   'CAP2',
#   'PDLIM3',
#   'RASD1',
#   'CNN1',
#   'PPARGC1B',
#   'RGS4',
#   'PTP4A3',
#   'COX4I2',
#   'ETNK2',
#   'BCR',
#   'VPS37B',
#   'KCNAB1',
#   'TCF15',
#   'RRAD',
#   'BCAM',
#   'SERPINI1',
#   'PPM1L',
#   'BCAR3',
#   'Zak',
#   'MYLK',
#   'RASL11A',
#   'TBX2',
#   'AOC3',
#   'MCAM',
#   'ATP1A2',
#   'TINAGL1',
#   'SPARCL1',
#   'MAMDC2',
#   'NDUFA4L2',
#   'FLNA',
#   'PPP1R12A',
#   'SCN2B',
#   'NR4A2',
#   'PTGES3L',
#   'INPP5A',
#   'MLF1',
#   'UBA2',
#   'RND2',
#   'LBH',
#   'ITGA7',
#   'HSPB2',
#   'NAT14',
#   'PPP1R12C',
#   'TMEM38A',
#   'RCSD1',
#   'CCDC3',
#   'GPRC5C',
#   'PDE1A',
#   'CCRL2',
#   'CHN1',
#   'RASAL2',
#   'ART3',
#   'ADAMTS4',
#   'SPEG',
#   'NEXN',
#   'PRKAG2',
#   'ATP1B1',
#   'RCAN2',
#   'RASSF3',
#   'USP2',
#   'BCAS3',
#   'ENTPD1'],
#  'Schwann cells_degs': ['MAP6D1',
#   'ST18',
#   'DSCAML1',
#   'OLIG2',
#   'Haglr',
#   'PLP1',
#   'LRP1B',
#   'MOG',
#   'ELAVL3',
#   'MAG',
#   'S1PR5',
#   'MAL',
#   'ERMN',
#   'NKAIN2',
#   'KCNK13',
#   'APLP1',
#   'TMPRSS5',
#   'OLIG1',
#   'MOBP',
#   'SEZ6L2',
#   'CLDN11',
#   'FA2H',
#   'SPOCK3',
#   'CMTM5',
#   'SOGA3',
#   'UGT8',
#   'SLAIN1',
#   'HEPACAM',
#   'ANKUB1',
#   'GPR37',
#   'GJB1',
#   'MBP',
#   'RAB37',
#   'Cyp2j12',
#   'PLLP',
#   'OMG',
#   'SV2A',
#   'PHYHIPL',
#   'PPP2R2C',
#   'Gm15440',
#   'PEX5L',
#   'PRR18',
#   'GATM',
#   'NKX2-2',
#   'TMEM88B',
#   'HAPLN2',
#   'ST8SIA5',
#   'CNP',
#   'TMEM151A',
#   'NKX6-2',
#   'NIPAL4',
#   'NKX2-8',
#   'PLS1',
#   'PCSK1N',
#   'HCN2',
#   'CA14',
#   'TUBB4A',
#   'GRM3',
#   'GALNT6',
#   'KLK6',
#   'SOX10',
#   'SHISA8',
#   'ADAP1',
#   'GPR62',
#   'TMEFF1',
#   'HOXD1',
#   'ADORA1',
#   'EVI2A',
#   'TMEM125',
#   'PAK5',
#   'GJC2',
#   'SLC24A2',
#   'EFNB3',
#   'PADI2',
#   'KCNJ10',
#   'ELOVL7',
#   'ADSS1',
#   'SERPIND1',
#   'SLC34A3',
#   'WSCD1',
#   'GPD1',
#   'STMN4',
#   'LRRC4B',
#   'KIF1A',
#   'MYRF',
#   'ANLN',
#   'CTNNA2',
#   'PCDH9',
#   'KCNA1',
#   'SCG5',
#   'OPALIN',
#   'CADM4',
#   'BCAS1',
#   'NFE2L3',
#   'PPP1R14A',
#   'IGSF11',
#   'HOPX',
#   '1700047M11Rik',
#   'TNNI1',
#   'ALDOC'],
#  'Ng2+ MSCs_degs': ['SPP1',
#   'DMP1',
#   'MMP13',
#   'VDR',
#   'SLIT2',
#   'TIMP1',
#   'COL13A1',
#   'IL12A',
#   'FAM78B',
#   'PTPRZ1',
#   'POSTN',
#   'SEMA7A',
#   'BMP3',
#   'FAM20C',
#   'ANKH',
#   'BGLAP',
#   'LRP4',
#   'TNC',
#   'HPGD',
#   'Wisp1',
#   'IFITM5',
#   'VLDLR',
#   'CTSC',
#   'PTGIS',
#   'BGLAP',
#   'CA3',
#   'ENPP1',
#   'SP7',
#   'PPFIBP2',
#   'CADM1',
#   'TSPAN6',
#   'ANGPT4',
#   'SATB2',
#   'SRPX2',
#   'SLC36A2',
#   'INSC',
#   'BGLAP',
#   'PTH1R',
#   'FAP',
#   'IBSP',
#   'MEF2C',
#   'SERPINE2',
#   'PARD6G',
#   'EXOC1',
#   'GPC1',
#   'HVCN1',
#   'DAPK2',
#   'UNC5B',
#   'DLX5',
#   'SDC3',
#   'SHOX2',
#   'LIFR',
#   'NRP2',
#   'RUNX2',
#   'WIF1',
#   'TGFB1',
#   'PAK1',
#   'ALPL',
#   'ST6GALNAC4',
#   '2700038G22Rik',
#   'FAT1',
#   'Cfh',
#   'RAPH1',
#   'RAMP1',
#   'CDC42EP3',
#   'CPE',
#   'CD200',
#   'CGREF1',
#   'ITGB5',
#   'SH3PXD2B',
#   'OLFML3',
#   'PODNL1',
#   'CNN2',
#   'EMILIN1',
#   'QSOX1',
#   'CREB3L1',
#   'Nradd',
#   'COL1A1',
#   'LIMCH1',
#   'BIN1',
#   'AC004691.2',
#   'BMP1',
#   'RGS3',
#   'SDC1',
#   'PPIC',
#   'SLC39A14',
#   'SGMS2',
#   'Gm26917',
#   'PTPRS',
#   'MSMP',
#   'TLE2',
#   'VSTM4',
#   'RYK',
#   'MAF',
#   'TSPAN4',
#   'ADARB1',
#   'TNS3',
#   'CDH2',
#   'CTNNB1',
#   'NME1'],
#  'Adipo-CAR_degs': ['HP',
#   'ADIPOQ',
#   'IL1RN',
#   'LPL',
#   'KNG1',
#   'CBLN1',
#   'SERPINA12',
#   'KNG1',
#   'AGT',
#   'PDZRN4',
#   'SERPINA3',
#   'ESM1',
#   'CXCL12',
#   'Gm4951',
#   'GDPD2',
#   'GREM1',
#   'C12orf75',
#   'CHRDL1',
#   'WDR86',
#   'LEPR',
#   'H2-Q10',
#   'GPR88',
#   'PAPPA',
#   'KITLG',
#   'Marc1',
#   'SPON1',
#   'FAM13A',
#   'FST',
#   'DPEP1',
#   'SHROOM3',
#   'TMEM176B',
#   'CCL19',
#   'MME',
#   'CD1D',
#   'ALDH1A2',
#   'IL34',
#   'ACKR4',
#   'GGT5',
#   'S1PR3',
#   'CYP1B1',
#   'EBF3',
#   'TMEM176A',
#   'ARRDC4',
#   'PTX3',
#   'LTBP2',
#   'CSMD1',
#   'FHL2',
#   'GHR',
#   'IFITM3',
#   'FGF7',
#   'PTGFR',
#   'Wisp2',
#   'SMOC1',
#   'IL7',
#   'CXCL14',
#   'SNAI2',
#   'CEBPA',
#   'GAS6',
#   'RSPO3',
#   'TMEM86A',
#   'Fam69a',
#   'TF',
#   'MYLK',
#   'Amy1',
#   'H2-Q7',
#   'APOE',
#   'FBLN5',
#   'DDIT4L',
#   'PODNL1',
#   'H2-D1',
#   'PLAC8',
#   'VEGFC',
#   'C4A',
#   'MDK',
#   'IBSP',
#   'RASA3',
#   'CDH11',
#   'TMEM51',
#   'H2-K1',
#   'IL1R1',
#   'SAMHD1',
#   'Iigp1',
#   'ANGPTL4',
#   'TNS3',
#   'EPAS1',
#   'FOXC1',
#   'BASP1',
#   'EVA1A',
#   'St5',
#   'ID4',
#   'ST3GAL6',
#   'IGFBP3',
#   'NNMT',
#   'PPARG',
#   'TPM1',
#   'G0S2',
#   'PDGFRB',
#   'NRP1',
#   'IRX3',
#   'CPXM1'],
#  'Osteo-CAR_degs': ['ANGPT4',
#   'KCNK2',
#   'WIF1',
#   'LIMCH1',
#   'SLC36A2',
#   'ALPL',
#   'HVCN1',
#   'TNC',
#   'NDNF',
#   'CLDN10',
#   'Gm20619',
#   'A2M',
#   'TNFRSF19',
#   'SP7',
#   'H2-Q6',
#   'DLX5',
#   'PI15',
#   'SLC20A2',
#   'RGS3',
#   'SMAD6',
#   'PLXNA2',
#   'LIFR',
#   'DAPK2',
#   'MMP13',
#   'LRP4',
#   'PTH1R',
#   'LMO7',
#   'HEY1',
#   'SDC3',
#   'COL8A1',
#   'RSPO3',
#   'SLC40A1',
#   'TLE2',
#   'EVA1A',
#   'IL7',
#   'OLFML3',
#   'GDF10',
#   'CADM1',
#   'FGFR3',
#   'RMND1',
#   'FGFR2',
#   'S100B',
#   'SHOX2',
#   'ADAMTS9',
#   'CDH11',
#   'FAT1',
#   'CDH2',
#   'GJA1',
#   'CLMP',
#   'ST6GALNAC4',
#   'RAI14',
#   'RUNX2',
#   'S1PR1',
#   'PTPRD',
#   'PALLD',
#   'TPM1',
#   'Marc1',
#   'SLIT3',
#   'PAPPA',
#   'CHST2',
#   'FBLN5',
#   'CXCL14',
#   'ARRDC4',
#   'PODNL1',
#   'GGT5',
#   'ST3GAL6',
#   'CXCL12',
#   'FHL2',
#   'VLDLR',
#   'SGMS2',
#   'TMEM86A',
#   'IGFBP4',
#   'ZEB2',
#   'CDC42EP1',
#   'Fam69a',
#   'CLEC11A',
#   'ACKR4',
#   'H2-K1',
#   'ZNF22',
#   'CP',
#   'WDR86',
#   'AUTS2',
#   'CNN2',
#   'GAS6',
#   'H2-Q4',
#   'PTGFR',
#   'FAP',
#   'B2M',
#   'IRX3',
#   'TNS3',
#   'MDFI',
#   'RBP4',
#   'LMO4',
#   'SERPINE2',
#   'MAF',
#   'H2-Q7',
#   'LIMD2',
#   'OMD',
#   'MMP14',
#   'MPP6'],
#  'Osteoblasts_degs': ['IFITM5',
#   'BGLAP',
#   'BGLAP',
#   'CPZ',
#   'BGLAP',
#   'CA3',
#   'Col24a1',
#   'LIPC',
#   'CGREF1',
#   'ENTPD3',
#   'MLIP',
#   'Col22a1',
#   'CHST13',
#   'COL11A2',
#   'CADM1',
#   'COL13A1',
#   'CTHRC1',
#   'FKBP11',
#   'KCNK1',
#   'SLC36A2',
#   'RP23-457J22.1',
#   'Gm266',
#   'CDO1',
#   'SMPD3',
#   'RCOR2',
#   'RASSF4',
#   'DKK1',
#   'Wisp1',
#   'LPAR3',
#   'COL11A1',
#   'KAZALD1',
#   'INSC',
#   'TCF7',
#   'RHBDL2',
#   'FABP3',
#   'FARP2',
#   'CHN1',
#   'RERG',
#   'COL1A1',
#   'RAMP1',
#   'SATB2',
#   'GALE',
#   'ITGA10',
#   'CPE',
#   'SGMS2',
#   'SP7',
#   'BMP3',
#   'ARHGEF19',
#   'MEF2C',
#   'PYCR1',
#   'TBX2',
#   'CREB3L1',
#   'PLA2G5',
#   'Shc2',
#   'BC026585',
#   'GUCA1A',
#   'GPRC5C',
#   'PACSIN1',
#   'PTGIS',
#   'MMP16',
#   'FAM110D',
#   'SATB1',
#   'PTH1R',
#   'TMEM119',
#   'CACNB3',
#   'GNE',
#   'ZNF652',
#   'FAM221B',
#   'NT5DC2',
#   'ZBTB7C',
#   'VDR',
#   'NRP2',
#   'Snhg18',
#   'P3H1',
#   'KDELR3',
#   'HSPB2',
#   'PDIA5',
#   'COL5A2',
#   'ENPP6',
#   'SPNS2',
#   'GXYLT2',
#   'FKBP7',
#   'ME2',
#   'FAM78B',
#   'GPC1',
#   'Fam46a',
#   'FKBP10',
#   'CKAP4',
#   'DAPK2',
#   'ELL2',
#   '2700038G22Rik',
#   'HPGD',
#   'PTPRZ1',
#   'PPFIBP2',
#   'SEC61B',
#   'COPZ2',
#   'PARD6G',
#   'GMPPB',
#   'FAP',
#   'BCAR3'],
#  'Fibro/Chondro p._degs': ['CILP2',
#   'CHAD',
#   'FMOD',
#   'NDUFA4L2',
#   'Mfi2',
#   'CYTL1',
#   'NT5E',
#   '1500015O10Rik',
#   'SUSD5',
#   'PRG4',
#   'ACAN',
#   'HAPLN1',
#   'FIBIN',
#   'COMP',
#   'TNFRSF11B',
#   'Dhx58os',
#   'CILP',
#   'FAM180A',
#   'COL8A2',
#   'SCRG1',
#   'ANXA8',
#   'NGEF',
#   'LGALS3',
#   'WIF1',
#   'CLU',
#   'MFGE8',
#   'ENPP1',
#   'STK38L',
#   'SHISA2',
#   'IVNS1ABP',
#   'EPS8L2',
#   'SOX9',
#   'RBP4',
#   'HBEGF',
#   'SPP1',
#   'OMD',
#   'COX4I2',
#   'P4HA2',
#   '3110079O15Rik',
#   'DUSP14',
#   'SDK2',
#   'Fxyd5',
#   'CDO1',
#   'ANKH',
#   'CRISPLD1',
#   'NR4A2',
#   'KIAA0040',
#   'HIGD1A',
#   'RGCC',
#   'TSC22D1',
#   'COL11A1',
#   'CDC42EP3',
#   'SOD3',
#   'PLOD2',
#   'CPE',
#   'NINJ1',
#   'PRELP',
#   'WWP2',
#   'CGREF1',
#   'ADK',
#   'SLC20A1',
#   'TOB1',
#   'THBS4',
#   'TSPAN2',
#   'HOXC10',
#   'COL27A1',
#   'BNIP3',
#   'MARVELD1',
#   'P3H2',
#   'DKK3',
#   'FN1',
#   'Cd24a',
#   'MGP',
#   'SDC4',
#   'S100A4',
#   'PKM',
#   'Vimp',
#   'COL6A3',
#   'Fam134b',
#   'BMP2',
#   'GPSM2',
#   'CST3',
#   'Col9a3',
#   'PTGIS',
#   'BHLHE40',
#   'P4HA1',
#   'TSPAN3',
#   'MPP6',
#   'LOXL3',
#   'HTRA1',
#   'PFKP',
#   'ECM2',
#   'KLF2',
#   'CD109',
#   'COL16A1',
#   'CHST12',
#   'ENO1',
#   'SPSB2',
#   'IQSEC1',
#   'DAB2'],
#  'Chondrocytes_degs': ['SERPINA1',
#   'COL2A1',
#   'MATN3',
#   'COL9A1',
#   'Lect1',
#   'UCMA',
#   '3110079O15Rik',
#   'COL9A2',
#   'MIA-RAB4B',
#   'Col9a3',
#   'SCRG1',
#   'HAPLN1',
#   'SERPINA1',
#   'FXYD2',
#   'ACAN',
#   'NCMAP',
#   'SERPINA1',
#   'SERPINA1',
#   'Wisp3',
#   'SYT8',
#   'Mfi2',
#   'FAM89A',
#   'CYTL1',
#   'CHADL',
#   'FOXA3',
#   'COL11A1',
#   'COL27A1',
#   'SERPINA1',
#   'COL11A2',
#   'SUSD5',
#   'PPP1R1B',
#   'EFCAB1',
#   'TRPV4',
#   'CHAD',
#   'Dhx58os',
#   'CHI3L1',
#   'PRSS50',
#   'CALML3',
#   'STK26',
#   'EPYC',
#   'NOTUM',
#   'SLC16A4',
#   'KCTD4',
#   'PAPSS2',
#   'PLA2G5',
#   'GRAMD2A',
#   'CRISPLD1',
#   'SLC38A3',
#   'FXYD3',
#   'PRKG2',
#   'COBLL1',
#   'STEAP1',
#   'WWP2',
#   'COX4I2',
#   'CHST11',
#   'SOX9',
#   'Fam101a',
#   '1500015O10Rik',
#   'SCIN',
#   'TNFRSF11B',
#   'FMOD',
#   'SOX5',
#   'XYLT1',
#   'COLGALT2',
#   'COMP',
#   'NRTN',
#   'SEMA3D',
#   'CSPG4',
#   '2810001G20Rik',
#   'RARRES1',
#   'FAM180A',
#   'BHLHE41',
#   'NT5E',
#   'CA12',
#   'AL645941.2',
#   'NINJ2',
#   'RCAN1',
#   'KCNMA1',
#   'HHIP',
#   'PPA1',
#   'PLOD2',
#   'LGALS3',
#   'HBEGF',
#   'CLDN12',
#   'AI646519',
#   'Cd24a',
#   'TSC22D1',
#   'FGFR3',
#   'PRR5',
#   'PAX1',
#   'SMIM5',
#   'MDFI',
#   'OMD',
#   'SLC26A2',
#   'FZD9',
#   'SLC35E3',
#   'M1AP',
#   'IL17D',
#   'MFGE8',
#   'GALE']}

# %% [markdown]
# # Run cell cycle score comparisons

# %%
adata = scrna_data

# %%
# run through DEG list for each cell type, run score_genes function on adata object for these genes and save in .obs
celltypes_string_list = list(my_dict.keys())

DEG_lists=my_dict.values()
counter=0

for i in DEG_lists:
    sc.tl.score_genes(adata, gene_list=i, score_name=celltypes_string_list[counter])
    counter=counter+1
# Out:
# WARNING: gene: Ctla2a is not in adata.var_names and will be ignored
# WARNING: gene: Clca3a1 is not in adata.var_names and will be ignored
# WARNING: gene: Pvrl2 is not in adata.var_names and will be ignored
# WARNING: gene: AC004691.2 is not in adata.var_names and will be ignored
# WARNING: gene: Sepp1 is not in adata.var_names and will be ignored
# WARNING: gene: Bvht is not in adata.var_names and will be ignored
# WARNING: gene: Abcg2 is not in adata.var_names and will be ignored
# WARNING: gene: Ceacam1 is not in adata.var_names and will be ignored
# WARNING: gene: 8430408G22Rik is not in adata.var_names and will be ignored
# WARNING: gene: Nebl is not in adata.var_names and will be ignored
# WARNING: gene: AC015802.6 is not in adata.var_names and will be ignored
# WARNING: gene: Fam101b is not in adata.var_names and will be ignored
# WARNING: gene: Sdpr is not in adata.var_names and will be ignored
# WARNING: gene: Ifi27l2a is not in adata.var_names and will be ignored
# WARNING: gene: Ly6a is not in adata.var_names and will be ignored
# WARNING: gene: Ly6c1 is not in adata.var_names and will be ignored
# WARNING: gene: Ccdc109b is not in adata.var_names and will be ignored
# WARNING: gene: Nov is not in adata.var_names and will be ignored
# WARNING: gene: Prkcdbp is not in adata.var_names and will be ignored
# WARNING: gene: AL162231.3 is not in adata.var_names and will be ignored
# WARNING: gene: SLC66A3 is not in adata.var_names and will be ignored
# WARNING: gene: Mxra7 is not in adata.var_names and will be ignored
# WARNING: gene: Nov is not in adata.var_names and will be ignored
# WARNING: gene: Abca8a is not in adata.var_names and will be ignored
# WARNING: gene: Meg3 is not in adata.var_names and will be ignored
# WARNING: gene: Rpl17 is not in adata.var_names and will be ignored
# WARNING: gene: Rplp0 is not in adata.var_names and will be ignored
# WARNING: gene: Gm16833 is not in adata.var_names and will be ignored
# WARNING: gene: Rps7 is not in adata.var_names and will be ignored
# WARNING: gene: Rpl14 is not in adata.var_names and will be ignored
# WARNING: gene: Gm8730 is not in adata.var_names and will be ignored
# WARNING: gene: Rpl36a is not in adata.var_names and will be ignored
# WARNING: gene: Eef1a1 is not in adata.var_names and will be ignored
# WARNING: gene: Rpl24 is not in adata.var_names and will be ignored
# WARNING: gene: Rpl6l is not in adata.var_names and will be ignored
# WARNING: gene: Gm15013 is not in adata.var_names and will be ignored
# WARNING: gene: Rpl7 is not in adata.var_names and will be ignored
# WARNING: gene: Rpl21 is not in adata.var_names and will be ignored
# WARNING: gene: Gm9493 is not in adata.var_names and will be ignored
# WARNING: gene: Cxcl1 is not in adata.var_names and will be ignored
# WARNING: gene: Abca8a is not in adata.var_names and will be ignored
# WARNING: gene: Nov is not in adata.var_names and will be ignored
# WARNING: gene: Dnaja1 is not in adata.var_names and will be ignored
# WARNING: gene: Map3k7cl is not in adata.var_names and will be ignored
# WARNING: gene: Gucy1a3 is not in adata.var_names and will be ignored
# WARNING: gene: Gm13861 is not in adata.var_names and will be ignored
# WARNING: gene: Gucy1b3 is not in adata.var_names and will be ignored
# WARNING: gene: Zak is not in adata.var_names and will be ignored
# WARNING: gene: Haglr is not in adata.var_names and will be ignored
# WARNING: gene: Cyp2j12 is not in adata.var_names and will be ignored
# WARNING: gene: Gm15440 is not in adata.var_names and will be ignored
# WARNING: gene: PAK5 is not in adata.var_names and will be ignored
# WARNING: gene: ADSS1 is not in adata.var_names and will be ignored
# WARNING: gene: 1700047M11Rik is not in adata.var_names and will be ignored
# WARNING: gene: Wisp1 is not in adata.var_names and will be ignored
# WARNING: gene: 2700038G22Rik is not in adata.var_names and will be ignored
# WARNING: gene: Cfh is not in adata.var_names and will be ignored
# WARNING: gene: Nradd is not in adata.var_names and will be ignored
# WARNING: gene: AC004691.2 is not in adata.var_names and will be ignored
# WARNING: gene: Gm26917 is not in adata.var_names and will be ignored
# WARNING: gene: Gm4951 is not in adata.var_names and will be ignored
# WARNING: gene: H2-Q10 is not in adata.var_names and will be ignored
# WARNING: gene: Marc1 is not in adata.var_names and will be ignored
# WARNING: gene: Wisp2 is not in adata.var_names and will be ignored
# WARNING: gene: Fam69a is not in adata.var_names and will be ignored
# WARNING: gene: Amy1 is not in adata.var_names and will be ignored
# WARNING: gene: H2-Q7 is not in adata.var_names and will be ignored
# WARNING: gene: H2-D1 is not in adata.var_names and will be ignored
# WARNING: gene: H2-K1 is not in adata.var_names and will be ignored
# WARNING: gene: Iigp1 is not in adata.var_names and will be ignored
# WARNING: gene: St5 is not in adata.var_names and will be ignored
# WARNING: gene: Gm20619 is not in adata.var_names and will be ignored
# WARNING: gene: H2-Q6 is not in adata.var_names and will be ignored
# WARNING: gene: Marc1 is not in adata.var_names and will be ignored
# WARNING: gene: Fam69a is not in adata.var_names and will be ignored
# WARNING: gene: H2-K1 is not in adata.var_names and will be ignored
# WARNING: gene: H2-Q4 is not in adata.var_names and will be ignored
# WARNING: gene: H2-Q7 is not in adata.var_names and will be ignored
# WARNING: gene: Col24a1 is not in adata.var_names and will be ignored
# WARNING: gene: Col22a1 is not in adata.var_names and will be ignored
# WARNING: gene: RP23-457J22.1 is not in adata.var_names and will be ignored
# WARNING: gene: Gm266 is not in adata.var_names and will be ignored
# WARNING: gene: Wisp1 is not in adata.var_names and will be ignored
# WARNING: gene: Shc2 is not in adata.var_names and will be ignored
# WARNING: gene: BC026585 is not in adata.var_names and will be ignored
# WARNING: gene: Snhg18 is not in adata.var_names and will be ignored
# WARNING: gene: Fam46a is not in adata.var_names and will be ignored
# WARNING: gene: 2700038G22Rik is not in adata.var_names and will be ignored
# WARNING: gene: Mfi2 is not in adata.var_names and will be ignored
# WARNING: gene: 1500015O10Rik is not in adata.var_names and will be ignored
# WARNING: gene: Dhx58os is not in adata.var_names and will be ignored
# WARNING: gene: 3110079O15Rik is not in adata.var_names and will be ignored
# WARNING: gene: Fxyd5 is not in adata.var_names and will be ignored
# WARNING: gene: Cd24a is not in adata.var_names and will be ignored
# WARNING: gene: Vimp is not in adata.var_names and will be ignored
# WARNING: gene: Fam134b is not in adata.var_names and will be ignored
# WARNING: gene: Col9a3 is not in adata.var_names and will be ignored
# WARNING: gene: Lect1 is not in adata.var_names and will be ignored
# WARNING: gene: 3110079O15Rik is not in adata.var_names and will be ignored
# WARNING: gene: Col9a3 is not in adata.var_names and will be ignored
# WARNING: gene: Wisp3 is not in adata.var_names and will be ignored
# WARNING: gene: Mfi2 is not in adata.var_names and will be ignored
# WARNING: gene: Dhx58os is not in adata.var_names and will be ignored
# WARNING: gene: GRAMD2A is not in adata.var_names and will be ignored
# WARNING: gene: Fam101a is not in adata.var_names and will be ignored
# WARNING: gene: 1500015O10Rik is not in adata.var_names and will be ignored
# WARNING: gene: 2810001G20Rik is not in adata.var_names and will be ignored
# WARNING: gene: AL645941.2 is not in adata.var_names and will be ignored
# WARNING: gene: AI646519 is not in adata.var_names and will be ignored
# WARNING: gene: Cd24a is not in adata.var_names and will be ignored

# %%
# save cell cycle scores within metadata as a dataframe (called enrichement scores)
adata.obs["labels"] = adata.obs["cell.labels"]
meta = pd.DataFrame(adata.obs)
enrichment_scores_df = meta[meta.columns[-17:]]
enrichment_scores_df
# Out:
#                                                           april_cell.labels  \
# index
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_AACT...       stromal macrophage
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_AGTT...  monocytoid macrophage 2
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CAAG...       stromal macrophage
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CAGT...               osteoclast
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CATC...       stromal macrophage
# ...                                                                     ...
# TTACGCCGTACCCACG-1-WSSS_F_BON8710643                     stromal macrophage
# TTCCTTCGTGTGAATA-1-WSSS_F_BON8710643                     stromal macrophage
# TTGCCTGTCGTTCGCT-1-WSSS_F_BON8710643                     stromal macrophage
# TTTACGTAGCAGCCTC-1-WSSS_F_BON8710643                     stromal macrophage
# TTTCACAGTCACTTAG-1-WSSS_F_BON8710643                     stromal macrophage
#
#                                                         cell.labels_broad  \
# index
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_AACT...          EI macrophage
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_AGTT...  monocytoid macrophage
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CAAG...          EI macrophage
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CAGT...  monocytoid macrophage
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CATC...          EI macrophage
# ...                                                                   ...
# TTACGCCGTACCCACG-1-WSSS_F_BON8710643                monocytoid macrophage
# TTCCTTCGTGTGAATA-1-WSSS_F_BON8710643                           osteoclast
# TTGCCTGTCGTTCGCT-1-WSSS_F_BON8710643                monocytoid macrophage
# TTTACGTAGCAGCCTC-1-WSSS_F_BON8710643                monocytoid macrophage
# TTTCACAGTCACTTAG-1-WSSS_F_BON8710643                           osteoclast
#
#                                                     Sinusoidal ECs_degs  \
# index
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_AACT...            -0.025819
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_AGTT...            -0.042702
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CAAG...            -0.041717
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CAGT...            -0.099947
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CATC...            -0.019950
# ...                                                                 ...
# TTACGCCGTACCCACG-1-WSSS_F_BON8710643                           0.108857
# TTCCTTCGTGTGAATA-1-WSSS_F_BON8710643                          -0.037790
# TTGCCTGTCGTTCGCT-1-WSSS_F_BON8710643                          -0.147500
# TTTACGTAGCAGCCTC-1-WSSS_F_BON8710643                          -0.019367
# TTTCACAGTCACTTAG-1-WSSS_F_BON8710643                          -0.094735
#
#                                                     Arteriolar ECs_degs  \
# index
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_AACT...            -0.085361
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_AGTT...            -0.140423
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CAAG...            -0.161333
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CAGT...            -0.026950
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CATC...            -0.047267
# ...                                                                 ...
# TTACGCCGTACCCACG-1-WSSS_F_BON8710643                          -0.076246
# TTCCTTCGTGTGAATA-1-WSSS_F_BON8710643                          -0.036073
# TTGCCTGTCGTTCGCT-1-WSSS_F_BON8710643                          -0.151870
# TTTACGTAGCAGCCTC-1-WSSS_F_BON8710643                           0.017645
# TTTCACAGTCACTTAG-1-WSSS_F_BON8710643                          -0.023359
#
#                                                     Endosteal fibro._degs  \
# index
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_AACT...              -0.039919
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_AGTT...               0.024769
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CAAG...              -0.075507
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CAGT...              -0.030613
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CATC...              -0.050165
# ...                                                                   ...
# TTACGCCGTACCCACG-1-WSSS_F_BON8710643                            -0.084472
# TTCCTTCGTGTGAATA-1-WSSS_F_BON8710643                             0.039358
# TTGCCTGTCGTTCGCT-1-WSSS_F_BON8710643                            -0.109227
# TTTACGTAGCAGCCTC-1-WSSS_F_BON8710643                             0.094185
# TTTCACAGTCACTTAG-1-WSSS_F_BON8710643                             0.077656
#
#                                                     Arteriolar fibro._degs  \
# index
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_AACT...               -0.102020
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_AGTT...               -0.159262
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CAAG...               -0.113604
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CAGT...               -0.052029
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CATC...               -0.048006
# ...                                                                    ...
# TTACGCCGTACCCACG-1-WSSS_F_BON8710643                             -0.023667
# TTCCTTCGTGTGAATA-1-WSSS_F_BON8710643                             -0.008374
# TTGCCTGTCGTTCGCT-1-WSSS_F_BON8710643                             -0.135107
# TTTACGTAGCAGCCTC-1-WSSS_F_BON8710643                             -0.109133
# TTTCACAGTCACTTAG-1-WSSS_F_BON8710643                             -0.117890
#
#                                                     Myofibroblasts_degs  \
# index
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_AACT...            -0.021525
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_AGTT...            -0.053318
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CAAG...            -0.094465
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CAGT...             0.197441
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CATC...            -0.050134
# ...                                                                 ...
# TTACGCCGTACCCACG-1-WSSS_F_BON8710643                           0.195516
# TTCCTTCGTGTGAATA-1-WSSS_F_BON8710643                           0.406614
# TTGCCTGTCGTTCGCT-1-WSSS_F_BON8710643                           0.316497
# TTTACGTAGCAGCCTC-1-WSSS_F_BON8710643                           0.236632
# TTTCACAGTCACTTAG-1-WSSS_F_BON8710643                           0.278145
#
#                                                     Stromal fibro._degs  \
# index
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_AACT...            -0.061407
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_AGTT...            -0.037814
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CAAG...            -0.048737
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CAGT...             0.015425
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CATC...            -0.010271
# ...                                                                 ...
# TTACGCCGTACCCACG-1-WSSS_F_BON8710643                          -0.024365
# TTCCTTCGTGTGAATA-1-WSSS_F_BON8710643                          -0.102884
# TTGCCTGTCGTTCGCT-1-WSSS_F_BON8710643                           0.027113
# TTTACGTAGCAGCCTC-1-WSSS_F_BON8710643                           0.052539
# TTTCACAGTCACTTAG-1-WSSS_F_BON8710643                           0.003358
#
#                                                     Smooth muscle_degs  \
# index
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_AACT...           -0.044346
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_AGTT...           -0.045403
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CAAG...           -0.031276
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CAGT...           -0.152980
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CATC...           -0.015111
# ...                                                                ...
# TTACGCCGTACCCACG-1-WSSS_F_BON8710643                          0.099619
# TTCCTTCGTGTGAATA-1-WSSS_F_BON8710643                          0.028139
# TTGCCTGTCGTTCGCT-1-WSSS_F_BON8710643                         -0.041409
# TTTACGTAGCAGCCTC-1-WSSS_F_BON8710643                          0.059025
# TTTCACAGTCACTTAG-1-WSSS_F_BON8710643                         -0.075713
#
#                                                     Schwann cells_degs  \
# index
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_AACT...           -0.028392
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_AGTT...           -0.047961
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CAAG...           -0.102970
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CAGT...            0.061131
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CATC...           -0.051413
# ...                                                                ...
# TTACGCCGTACCCACG-1-WSSS_F_BON8710643                         -0.001500
# TTCCTTCGTGTGAATA-1-WSSS_F_BON8710643                          0.066008
# TTGCCTGTCGTTCGCT-1-WSSS_F_BON8710643                         -0.007146
# TTTACGTAGCAGCCTC-1-WSSS_F_BON8710643                         -0.021078
# TTTCACAGTCACTTAG-1-WSSS_F_BON8710643                          0.003843
#
#                                                     Ng2+ MSCs_degs  \
# index
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_AACT...       -0.082506
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_AGTT...       -0.212909
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CAAG...       -0.087241
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CAGT...       -0.076203
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CATC...       -0.037423
# ...                                                            ...
# TTACGCCGTACCCACG-1-WSSS_F_BON8710643                     -0.019174
# TTCCTTCGTGTGAATA-1-WSSS_F_BON8710643                     -0.050157
# TTGCCTGTCGTTCGCT-1-WSSS_F_BON8710643                     -0.080330
# TTTACGTAGCAGCCTC-1-WSSS_F_BON8710643                     -0.041090
# TTTCACAGTCACTTAG-1-WSSS_F_BON8710643                     -0.178514
#
#                                                     Adipo-CAR_degs  \
# index
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_AACT...       -0.019459
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_AGTT...        0.039638
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CAAG...        0.053249
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CAGT...       -0.004765
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CATC...       -0.019407
# ...                                                            ...
# TTACGCCGTACCCACG-1-WSSS_F_BON8710643                      0.090430
# TTCCTTCGTGTGAATA-1-WSSS_F_BON8710643                     -0.042027
# TTGCCTGTCGTTCGCT-1-WSSS_F_BON8710643                     -0.008320
# TTTACGTAGCAGCCTC-1-WSSS_F_BON8710643                     -0.051959
# TTTCACAGTCACTTAG-1-WSSS_F_BON8710643                     -0.120205
#
#                                                     Osteo-CAR_degs  \
# index
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_AACT...       -0.049037
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_AGTT...       -0.198605
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CAAG...       -0.054648
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CAGT...       -0.031662
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CATC...       -0.027867
# ...                                                            ...
# TTACGCCGTACCCACG-1-WSSS_F_BON8710643                      0.071780
# TTCCTTCGTGTGAATA-1-WSSS_F_BON8710643                     -0.045572
# TTGCCTGTCGTTCGCT-1-WSSS_F_BON8710643                     -0.191220
# TTTACGTAGCAGCCTC-1-WSSS_F_BON8710643                     -0.090809
# TTTCACAGTCACTTAG-1-WSSS_F_BON8710643                     -0.086992
#
#                                                     Osteoblasts_degs  \
# index
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_AACT...         -0.068677
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_AGTT...         -0.170666
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CAAG...         -0.130501
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CAGT...         -0.102631
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CATC...         -0.053995
# ...                                                              ...
# TTACGCCGTACCCACG-1-WSSS_F_BON8710643                        0.119293
# TTCCTTCGTGTGAATA-1-WSSS_F_BON8710643                       -0.049649
# TTGCCTGTCGTTCGCT-1-WSSS_F_BON8710643                       -0.080747
# TTTACGTAGCAGCCTC-1-WSSS_F_BON8710643                        0.033306
# TTTCACAGTCACTTAG-1-WSSS_F_BON8710643                       -0.172584
#
#                                                     Fibro/Chondro p._degs  \
# index
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_AACT...               0.003233
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_AGTT...              -0.022257
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CAAG...              -0.042769
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CAGT...               0.002229
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CATC...              -0.026154
# ...                                                                   ...
# TTACGCCGTACCCACG-1-WSSS_F_BON8710643                             0.031362
# TTCCTTCGTGTGAATA-1-WSSS_F_BON8710643                             0.043374
# TTGCCTGTCGTTCGCT-1-WSSS_F_BON8710643                            -0.078801
# TTTACGTAGCAGCCTC-1-WSSS_F_BON8710643                             0.070472
# TTTCACAGTCACTTAG-1-WSSS_F_BON8710643                            -0.126315
#
#                                                     Chondrocytes_degs  \
# index
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_AACT...          -0.026444
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_AGTT...          -0.020818
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CAAG...          -0.121752
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CAGT...          -0.057937
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CATC...          -0.020609
# ...                                                               ...
# TTACGCCGTACCCACG-1-WSSS_F_BON8710643                        -0.071955
# TTCCTTCGTGTGAATA-1-WSSS_F_BON8710643                        -0.008319
# TTGCCTGTCGTTCGCT-1-WSSS_F_BON8710643                        -0.091548
# TTTACGTAGCAGCCTC-1-WSSS_F_BON8710643                        -0.034015
# TTTCACAGTCACTTAG-1-WSSS_F_BON8710643                        -0.035975
#
#                                                                    labels
# index
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_AACT...          EI macrophage
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_AGTT...  monocytoid macrophage
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CAAG...          EI macrophage
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CAGT...  monocytoid macrophage
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_CATC...          EI macrophage
# ...                                                                   ...
# TTACGCCGTACCCACG-1-WSSS_F_BON8710643                monocytoid macrophage
# TTCCTTCGTGTGAATA-1-WSSS_F_BON8710643                           osteoclast
# TTGCCTGTCGTTCGCT-1-WSSS_F_BON8710643                monocytoid macrophage
# TTTACGTAGCAGCCTC-1-WSSS_F_BON8710643                monocytoid macrophage
# TTTCACAGTCACTTAG-1-WSSS_F_BON8710643                           osteoclast
#
# [6726 rows x 17 columns]

# %%
# calculate mean enrichment scores by celltype
mean_enrichment_scores_df = enrichment_scores_df.groupby('labels').mean()
mean_enrichment_scores_df = mean_enrichment_scores_df.T
mean_enrichment_scores_df
# Out:
# labels                  stromal macrophage  monocytoid macrophage  \
# Sinusoidal ECs_degs              -0.024397              -0.048315
# Arteriolar ECs_degs              -0.064995              -0.074367
# Endosteal fibro._degs            -0.018689              -0.001380
# Arteriolar fibro._degs           -0.102599              -0.105099
# Myofibroblasts_degs              -0.033937               0.156100
# Stromal fibro._degs               0.009727              -0.010969
# Smooth muscle_degs               -0.075696              -0.071367
# Schwann cells_degs               -0.036085              -0.017266
# Ng2+ MSCs_degs                   -0.082363              -0.091102
# Adipo-CAR_degs                   -0.012323               0.000607
# Osteo-CAR_degs                   -0.099854              -0.100476
# Osteoblasts_degs                 -0.108590              -0.110291
# Fibro/Chondro p._degs            -0.031249              -0.029822
# Chondrocytes_degs                -0.049270              -0.057431
#
# labels                  EI macrophage  osteoclast  immature EC  sinusoidal EC  \
# Sinusoidal ECs_degs         -0.101894   -0.122626     0.507941       1.075244
# Arteriolar ECs_degs         -0.097567   -0.095820     0.499991       0.686669
# Endosteal fibro._degs       -0.029095    0.013479     0.038065       0.056080
# Arteriolar fibro._degs      -0.034276   -0.062421    -0.015833      -0.127717
# Myofibroblasts_degs          0.068803    0.130114     0.248767       0.031152
# Stromal fibro._degs          0.021412   -0.017320     0.103068       0.164111
# Smooth muscle_degs          -0.029491   -0.091511     0.007977      -0.042914
# Schwann cells_degs          -0.062986   -0.026549    -0.048575      -0.108952
# Ng2+ MSCs_degs               0.022236   -0.071804    -0.052927      -0.095724
# Adipo-CAR_degs              -0.001691   -0.055416     0.005734       0.015963
# Osteo-CAR_degs               0.006592   -0.097628    -0.010927      -0.054843
# Osteoblasts_degs             0.010519   -0.079037    -0.061966      -0.135271
# Fibro/Chondro p._degs        0.015864    0.012062    -0.025609      -0.071369
# Chondrocytes_degs            0.029496   -0.037209    -0.052897      -0.108773
#
# labels                  proliferating EC    tip EC  endosteal fibroblast  \
# Sinusoidal ECs_degs             0.830259  0.956527             -0.226194
# Arteriolar ECs_degs             0.777291  1.022002             -0.086986
# Endosteal fibro._degs           0.046305  0.170286              1.132436
# Arteriolar fibro._degs         -0.091452 -0.044248              0.934039
# Myofibroblasts_degs            -0.073994 -0.038394             -0.014378
# Stromal fibro._degs             0.170648  0.238099              0.482120
# Smooth muscle_degs             -0.001788  0.067051              0.173253
# Schwann cells_degs             -0.112689 -0.124209             -0.034755
# Ng2+ MSCs_degs                 -0.158143 -0.082024              0.054927
# Adipo-CAR_degs                 -0.034846 -0.008965              0.000388
# Osteo-CAR_degs                 -0.129038 -0.033829             -0.019480
# Osteoblasts_degs               -0.173047 -0.121385              0.108321
# Fibro/Chondro p._degs          -0.126311 -0.049443              0.667618
# Chondrocytes_degs              -0.127279 -0.118500              0.267449
#
# labels                  arteriolar fibroblast  myofibroblast    muscle  \
# Sinusoidal ECs_degs                 -0.155568      -0.141336 -0.140880
# Arteriolar ECs_degs                 -0.122273      -0.094320 -0.080176
# Endosteal fibro._degs                0.844720      -0.000687  0.018733
# Arteriolar fibro._degs               1.234428       0.071416  0.054922
# Myofibroblasts_degs                  0.009789       0.426458  0.596785
# Stromal fibro._degs                  0.668802       0.136887  0.147296
# Smooth muscle_degs                  -0.013953       0.070045  0.143665
# Schwann cells_degs                  -0.003644      -0.072840 -0.050432
# Ng2+ MSCs_degs                       0.145679       0.216868 -0.002361
# Adipo-CAR_degs                       0.155656       0.045670  0.025020
# Osteo-CAR_degs                       0.112647       0.179543  0.012103
# Osteoblasts_degs                     0.120984       0.121931 -0.006288
# Fibro/Chondro p._degs                0.288907       0.075781 -0.027059
# Chondrocytes_degs                    0.061642       0.116698 -0.029402
#
# labels                  schwann cells  osteochondral precursor  adipo-CAR  \
# Sinusoidal ECs_degs         -0.224159                -0.090184  -0.110460
# Arteriolar ECs_degs         -0.183469                -0.023342  -0.060954
# Endosteal fibro._degs        0.102095                 0.138280   0.151841
# Arteriolar fibro._degs      -0.048269                 0.383329   0.286207
# Myofibroblasts_degs         -0.125209                -0.032803  -0.025084
# Stromal fibro._degs          0.503330                 0.297310   0.399861
# Smooth muscle_degs           0.244751                 0.243331   0.052418
# Schwann cells_degs           0.744404                -0.070636  -0.053286
# Ng2+ MSCs_degs               0.021971                 0.467443   0.150022
# Adipo-CAR_degs               0.129695                 0.309969   0.809675
# Osteo-CAR_degs               0.007600                 0.418173   0.465497
# Osteoblasts_degs             0.009210                 0.155979  -0.047803
# Fibro/Chondro p._degs       -0.041752                 0.198304   0.112078
# Chondrocytes_degs           -0.038778                 0.119048   0.097105
#
# labels                  osteoblast precursor  early osteoblast  osteoblast  \
# Sinusoidal ECs_degs                -0.159070         -0.133726   -0.115476
# Arteriolar ECs_degs                -0.080015         -0.058655   -0.046227
# Endosteal fibro._degs               0.062398          0.054011    0.073015
# Arteriolar fibro._degs              0.282978          0.291188    0.287891
# Myofibroblasts_degs                 0.051252          0.065880    0.115143
# Stromal fibro._degs                 0.174441          0.174824    0.139015
# Smooth muscle_degs                 -0.007348          0.027445    0.021440
# Schwann cells_degs                 -0.064089         -0.072508   -0.036713
# Ng2+ MSCs_degs                      0.463055          0.767403    0.691444
# Adipo-CAR_degs                      0.206627          0.153742    0.008984
# Osteo-CAR_degs                      0.514385          0.452316    0.236231
# Osteoblasts_degs                    0.255524          0.600820    1.066488
# Fibro/Chondro p._degs               0.205184          0.254532    0.297011
# Chondrocytes_degs                   0.203021          0.167569    0.197535
#
# labels                  chondrocyte
# Sinusoidal ECs_degs       -0.146538
# Arteriolar ECs_degs       -0.013351
# Endosteal fibro._degs      0.118337
# Arteriolar fibro._degs     0.512287
# Myofibroblasts_degs        0.114429
# Stromal fibro._degs        0.290846
# Smooth muscle_degs         0.007033
# Schwann cells_degs        -0.033955
# Ng2+ MSCs_degs             0.143006
# Adipo-CAR_degs             0.046176
# Osteo-CAR_degs             0.146575
# Osteoblasts_degs           0.274978
# Fibro/Chondro p._degs      1.185326
# Chondrocytes_degs          1.617656

# %% [markdown]
# # Run heatmap

# %%
plt.figure(figsize=(10, 5))
fig = sns.heatmap(mean_enrichment_scores_df, annot=True, fmt=".2", center=0.4, annot_kws={"size": 5}, cmap="RdYlBu_r").get_figure()
fig.savefig("figures/fig4b_mouse_stroma_comparison_numbers_yes_20200512.pdf")
# plot gene scores as a heatmap. 
plt.figure(figsize=(10, 5))
fig = sns.heatmap(mean_enrichment_scores_df, cmap="RdYlBu_r", center=0.4).get_figure() 
fig.savefig("figures/fig4b_mouse_stroma_comparison_numbers_no_20200512.pdf")

# %% [markdown]
# # Save data

# %%
from scipy.sparse import csr_matrix
adata.X = sparse.csr_matrix(adata.X)

# %%
adata.X
# Out:
# <6726x33712 sparse matrix of type '<class 'numpy.float32'>'
# 	with 16105547 stored elements in Compressed Sparse Row format>

# %%
adata.raw.X
# Out:
# <6726x33712 sparse matrix of type '<class 'numpy.float32'>'
# 	with 17944923 stored elements in Compressed Sparse Row format>

# %%
adata.write("/Users/b8058304/Documents/PhD_work/Coding/manuscript_figs/data/figs4b_mouse_enrichment_comparison_20200512.h5ad")
