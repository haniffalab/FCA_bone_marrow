# %% [markdown]
# # Import packages and data

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import seaborn as sns
import scipy.stats
import anndata
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.axes._axes import _log as matplotlib_axes_logger
from scipy import sparse
matplotlib_axes_logger.setLevel('ERROR')
import warnings
warnings.filterwarnings('ignore')
# Out:
# /Users/b8058304/.pyenv/versions/3.6.4/envs/py36/lib/python3.6/site-packages/anndata/_core/anndata.py:21: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import RangeIndex

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
sc.settings.verbosity = 1  # verbosity: errors (0), warnings (1), info (2), hints (3)
# Set up the plot config for viewing the annotation clearly.
sc.settings.set_figure_params(dpi=120, dpi_save=1000)
sc.logging.print_versions()
# Out:
# scanpy==1.4.4 anndata==0.7.1 umap==0.3.10 numpy==1.18.1 scipy==1.4.1 pandas==1.0.2 scikit-learn==0.22.2.post1 statsmodels==0.11.1 python-igraph==0.8.0 louvain==0.6.1

# %% [markdown]
# # Load FBM transformed dataset

# %%
adata = sc.read("/Users/b8058304/Documents/PhD_work/Coding/manuscript_figs/data/fig1c_fbm_scaled_gex_updated_dr_20200428.h5ad")

# %%
cell_numbers = adata.obs.groupby(["broad_fig1_cell.labels"]).apply(len)
cell_numbers
# Out:
# broad_fig1_cell.labels
# HSC_MPP          7984
# erythroid       26591
# MK               2701
# B_lineage       28613
# DC               2460
# eo/baso/mast     1112
# neutrophil      10292
# monocyte        16733
# T_NK             1440
# stroma           6726
# dtype: int64

# %% [markdown]
# # Run the dotplots

# %%
genes = ['CD34', 'SPINK2', 'PRSS57', 'ALAS2', 'GYPA', 'KLF1', 'GP9', 'PLEK', 'ITGA2B', 'VPREB1', 'IGLL1', 'CD79A', 
        'CLEC10A', 'CD1C', 'HLA-DPA1', 'GATA2', 'HDC', 'PRG2', 'NCF1', 'ITGAM', 'PGLYRP1', 'CD14', 'CD68', 'CD52', 
        'CD3E', 'TRBC1', 'GZMA', 'MMP9', 'KDR', 'CTHRC1']

# %%
adata.obs["broad_fig1_cell.labels"] = adata.obs["broad_fig1_cell.labels"].cat.reorder_categories(['HSC_MPP', 
            'erythroid', 'MK', 'B_lineage', 'DC', 'eo/baso/mast', 'neutrophil', 'monocyte', 'T_NK', 'stroma'])

# %%
sc.settings.set_figure_params(dpi=100, dpi_save=1000)
sc.pl.dotplot(adata, var_names=genes, save="fig1e_overall_broad_dotplot_20200507.pdf", groupby="broad_fig1_cell.labels", use_raw=False)
# Out:
# WARNING: saving figure to file figures/dotplotfig1e_overall_broad_dotplot_20200507.pdf
# GridSpec(2, 5, height_ratios=[0, 10.5], width_ratios=[10.5, 0, 0.2, 0.5, 0.25])
