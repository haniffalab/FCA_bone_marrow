# %% [markdown]
# # Import packages and data

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import seaborn as sns
import scipy.stats
import anndata
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.axes._axes import _log as matplotlib_axes_logger
from scipy import sparse
matplotlib_axes_logger.setLevel('ERROR')
import warnings
warnings.filterwarnings('ignore')
# Out:
# /Users/b8058304/.pyenv/versions/3.6.4/envs/py36/lib/python3.6/site-packages/anndata/_core/anndata.py:21: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import RangeIndex

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
sc.settings.verbosity = 1  # verbosity: errors (0), warnings (1), info (2), hints (3)
# Set up the plot config for viewing the annotation clearly.
sc.settings.set_figure_params(dpi=120, dpi_save=1000)
sc.logging.print_versions()
# Out:
# scanpy==1.4.4 anndata==0.7.1 umap==0.3.10 numpy==1.17.1 scipy==1.4.1 pandas==1.0.5 scikit-learn==0.22.2.post1 statsmodels==0.11.1 python-igraph==0.8.0 louvain==0.6.1

# %% [markdown]
# # Load FBM transformed dataset

# %%
adata = sc.read("/Users/b8058304/Documents/PhD_work/Coding/manuscript_figs_mk2/data/fig1b_fbm_scaled_gex_updated_dr_20210104.h5ad")

# %%
cell_numbers = adata.obs.groupby(["broad_figS1_cell.labels"]).apply(len)
cell_numbers
# Out:
# broad_figS1_cell.labels
# B_lineage        28583
# CD14 monocyte     8763
# DC1                 50
# DC2                598
# DC_other          1099
# HSC_MPP           3795
# MK                2624
# T_NK              1349
# basophil           139
# eosinophil         321
# erythroid        26407
# mast cell          648
# myelocyte         3794
# neutrophil        4501
# pDC                712
# promonocyte      11275
# promyelocyte      2191
# stroma            6379
# dtype: int64

# %% [markdown]
# # Run the dotplots

# %%
genes = ['PTPRC', 
'IL3RA',
'HLA-DRA',
'CD34',
'KIT',
'IL5RA',
'CD79A',
'CD14',
'MSR1',
'CLEC9A',
'CD1C',
'CD52',
'ITGAM',
'CEACAM8']

# %%
adata.obs["broad_figS1_cell.labels"] = adata.obs["broad_figS1_cell.labels"].cat.reorder_categories(['erythroid', 
                'MK', 
                'stroma', 'basophil', 'pDC', 'HSC_MPP', 'mast cell', 'eosinophil', 'B_lineage', 'CD14 monocyte', 
                'promonocyte', 'DC1', 'DC2', 'DC_other', 'T_NK', 'neutrophil', 'myelocyte', 'promyelocyte'])

# %%
sc.settings.set_figure_params(dpi=100, dpi_save=1000)
sc.pl.dotplot(adata, var_names=genes, save="figs1b_overall_broad_dotplot_20210104.pdf", 
              groupby="broad_figS1_cell.labels", use_raw=False)
# Out:
# WARNING: saving figure to file figures/dotplotfigs1b_overall_broad_dotplot_20210104.pdf
# GridSpec(2, 5, height_ratios=[0, 10.5], width_ratios=[4.8999999999999995, 0, 0.2, 0.5, 0.25])
